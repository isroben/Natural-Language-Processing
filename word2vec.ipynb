# %%
import os
import gensim
from gensim.models import word2vec, KeyedVectors

# %%
model = KeyedVectors.load_word2vec_format(r'Data/GoogleNews-vectors-negative300.bin.gz', binary=True, limit=500000)

# %%
model['cricket']
# Out:
# array([-3.67187500e-01, -1.21582031e-01,  2.85156250e-01,  8.15429688e-02,
#         3.19824219e-02, -3.19824219e-02,  1.34765625e-01, -2.73437500e-01,
#         9.46044922e-03, -1.07421875e-01,  2.48046875e-01, -6.05468750e-01,
#         5.02929688e-02,  2.98828125e-01,  9.57031250e-02,  1.39648438e-01,
#        -5.41992188e-02,  2.91015625e-01,  2.85156250e-01,  1.51367188e-01,
#        -2.89062500e-01, -3.46679688e-02,  1.81884766e-02, -3.92578125e-01,
#         2.46093750e-01,  2.51953125e-01, -9.86328125e-02,  3.22265625e-01,
#         4.49218750e-01, -1.36718750e-01, -2.34375000e-01,  4.12597656e-02,
#        -2.15820312e-01,  1.69921875e-01,  2.56347656e-02,  1.50146484e-02,
#        -3.75976562e-02,  6.95800781e-03,  4.00390625e-01,  2.09960938e-01,
#         1.17675781e-01, -4.19921875e-02,  2.34375000e-01,  2.03125000e-01,
#        -1.86523438e-01, -2.46093750e-01,  3.12500000e-01, -2.59765625e-01,
#        -1.06933594e-01,  1.04003906e-01, -1.79687500e-01,  5.71289062e-02,
#        -7.41577148e-03, -5.59082031e-02,  7.61718750e-02, -4.14062500e-01,
#        -3.65234375e-01, -3.35937500e-01, -1.54296875e-01, -2.39257812e-01,
#        -3.73046875e-01,  2.27355957e-03, -3.51562500e-01,  8.64257812e-02,
#         1.26953125e-01,  2.21679688e-01, -9.86328125e-02,  1.08886719e-01,
#         3.65234375e-01, -5.66406250e-02,  5.66406250e-02, -1.09375000e-01,
#        -1.66992188e-01, -4.54101562e-02, -2.00195312e-01, -1.22558594e-01,
#         1.31835938e-01, -1.31835938e-01,  1.03027344e-01, -3.41796875e-01,
#        -1.57226562e-01,  2.04101562e-01,  4.39453125e-02,  2.44140625e-01,
#        -3.19824219e-02,  3.20312500e-01, -4.41894531e-02,  1.08398438e-01,
#        -4.98046875e-02, -9.52148438e-03,  2.46093750e-01, -5.59082031e-02,
#         4.07714844e-02, -1.78222656e-02, -2.95410156e-02,  1.65039062e-01,
#         5.03906250e-01, -2.81250000e-01,  9.81445312e-02,  1.80664062e-02,
#        -1.83593750e-01,  2.53906250e-01,  2.25585938e-01,  1.63574219e-02,
#         1.81640625e-01,  1.38671875e-01,  3.33984375e-01,  1.39648438e-01,
#         1.45874023e-02, -2.89306641e-02, -8.39843750e-02,  1.50390625e-01,
#         1.67968750e-01,  2.28515625e-01,  3.59375000e-01,  1.22558594e-01,
#        -3.28125000e-01, -1.56250000e-01,  2.77343750e-01,  1.77001953e-02,
#        -1.46484375e-01, -4.51660156e-03, -4.46777344e-02,  1.75781250e-01,
#        -3.75000000e-01,  1.16699219e-01, -1.39648438e-01,  2.55859375e-01,
#        -1.96289062e-01, -2.57568359e-02, -5.41992188e-02, -2.51464844e-02,
#        -1.93359375e-01, -3.17382812e-02, -8.74023438e-02, -1.32812500e-01,
#        -2.12402344e-02,  4.33593750e-01, -5.20019531e-02,  3.46679688e-02,
#         8.00781250e-02,  3.41796875e-02,  1.99218750e-01, -2.39257812e-02,
#        -2.37304688e-01,  1.93359375e-01,  7.32421875e-02, -2.87109375e-01,
#         1.25000000e-01,  8.44726562e-02,  1.30859375e-01, -2.19726562e-01,
#        -1.61132812e-01, -2.63671875e-01, -5.46875000e-01, -2.96875000e-01,
#         3.44238281e-02, -2.87109375e-01, -1.93359375e-01, -1.61132812e-01,
#        -3.84765625e-01, -2.14843750e-01, -6.22558594e-03, -1.27929688e-01,
#        -1.00097656e-01, -6.21093750e-01,  3.78906250e-01, -4.58984375e-01,
#         1.44531250e-01, -9.13085938e-02, -3.08593750e-01,  2.23632812e-01,
#         7.86132812e-02, -2.16796875e-01,  8.78906250e-02, -1.66992188e-01,
#         1.14746094e-02, -2.53906250e-01, -6.25000000e-02,  6.04248047e-03,
#         1.56250000e-01,  4.37500000e-01, -2.23632812e-01, -2.32421875e-01,
#         2.75390625e-01,  2.39257812e-01,  4.49218750e-02, -7.51953125e-02,
#         5.74218750e-01, -2.61230469e-02, -1.21582031e-01,  2.44140625e-01,
#        -3.37890625e-01,  8.59375000e-02, -7.71484375e-02,  4.85839844e-02,
#         1.43554688e-01,  4.25781250e-01, -4.29687500e-02, -1.08398438e-01,
#         1.19628906e-01, -1.91406250e-01, -2.12890625e-01, -2.87109375e-01,
#        -1.14746094e-01, -2.04101562e-01, -2.06298828e-02, -2.53906250e-01,
#         8.25195312e-02, -3.97949219e-02, -1.57226562e-01,  1.34765625e-01,
#         2.08007812e-01, -1.78710938e-01, -2.00195312e-02, -8.34960938e-02,
#        -1.20605469e-01,  4.29687500e-02, -1.94335938e-01, -1.32812500e-01,
#        -2.17285156e-02, -2.35351562e-01, -3.63281250e-01,  1.51367188e-01,
#         9.32617188e-02,  1.63085938e-01,  1.02050781e-01, -4.27734375e-01,
#         2.83203125e-01,  2.74658203e-04, -3.20312500e-01,  1.68457031e-02,
#         4.06250000e-01, -5.24902344e-02,  7.91015625e-02, -1.41601562e-01,
#         5.27343750e-01, -1.26953125e-01,  4.74609375e-01, -6.64062500e-02,
#         3.41796875e-01, -1.78710938e-01,  3.69140625e-01, -2.05078125e-01,
#         5.82885742e-03, -1.84570312e-01, -8.88671875e-02, -1.81640625e-01,
#        -4.80957031e-02,  4.39453125e-01,  2.12890625e-01, -3.07617188e-02,
#         9.32617188e-02,  2.40234375e-01,  2.39257812e-01,  2.51953125e-01,
#        -1.98974609e-02,  1.24511719e-01, -4.73632812e-02, -2.13623047e-02,
#         3.12500000e-02,  3.05175781e-02,  2.79296875e-01,  9.08203125e-02,
#        -2.02148438e-01, -2.19726562e-02, -2.63671875e-01,  8.78906250e-02,
#        -1.07421875e-01, -2.49023438e-01, -1.22070312e-02,  1.73828125e-01,
#        -9.91210938e-02,  7.27539062e-02,  2.59765625e-01, -4.60937500e-01,
#         3.59375000e-01, -2.25585938e-01,  1.87988281e-02, -2.19726562e-01,
#        -2.08984375e-01, -1.51367188e-01,  8.64257812e-02,  1.11694336e-02,
#         6.93359375e-02, -2.99072266e-02,  1.43554688e-01,  1.89453125e-01,
#        -1.32812500e-01,  4.72656250e-01, -1.40625000e-01, -2.52685547e-02,
#         1.91406250e-01, -2.63671875e-01, -1.39648438e-01,  1.09375000e-01,
#         1.97753906e-02,  2.49023438e-01, -1.42578125e-01,  4.15039062e-02],
#       dtype=float32)

# %%
model['cricket'].shape
# Out:
# (300,)

# %%
model.most_similar('facebook')
# Out:
# [('Facebook', 0.7563533186912537),
#  ('FaceBook', 0.7076998949050903),
#  ('twitter', 0.6988552212715149),
#  ('myspace', 0.6941817998886108),
#  ('Twitter', 0.664244532585144),
#  ('Facebook.com', 0.6529868245124817),
#  ('FacebookFacebook', 0.6162722110748291),
#  ('facebook.com', 0.6135972142219543),
#  ('Twitter.com', 0.6102108359336853),
#  ('TwitterTwitter', 0.6085205674171448)]

# %%
model.similarity('man', 'men')
# Out:
# np.float32(0.5489763)

# %%
model.similarity('man', 'PHP')
# Out:
# np.float32(-0.032995153)

# %%
model.doesnt_match(['PHP', 'java', 'monkey'])
# Out:
# 'monkey'

# %% [markdown]
# ## Training own Model

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
story = []
for filename in os.listdir(r'Data/GamesOfThrones'):
    f = open(os.path.join('Data/GamesOfThrones', filename), encoding='latin-1')
    corpus = f.read()
    raw_sent = sent_tokenize(corpus)
    
    for sent in raw_sent:
        story.append(simple_preprocess(sent))

# %%
story
# Out:
# [['storm',
#   'of',
#   'swords',
#   'book',
#   'three',
#   'of',
#   'song',
#   'of',
#   'ice',
#   'and',
#   'fire',
#   'by',
#   'george'],
#  ['martin',
#   'note',
#   'on',
#   'chronology',
#   'song',
#   'of',
#   'ice',
#   'and',
#   'fire',
#   'is',
#   'told',
#   'through',
#   'the',
#   'eyes',
#   'of',
#   'characters',
#   'who',
#   'are',
#   'sometimes',
#   'hundreds',
#   'or',
#   'even',
#   'thousands',
#   'of',
#   'miles',
#   'apart',
#   'from',
#   'one',
#   'another'],
#  ['some',
#   'chapters',
#   'cover',
#   'day',
#   'some',
#   'only',
#   'an',
#   'hour',
#   'others',
#   'might',
#   'span',
#   'fortnight',
#   'month',
#   'half',
#   'year'],
#  ['with',
#   'such',
#   'structure',
#   'the',
#   'narrative',
#   'cannot',
#   'be',
#   'strictly',
#   'sequential',
#   'sometimes',
#   'important',
#   'things',
#   'are',
#   'happening',
#   'simultaneously',
#   'thousand',
#   'leagues',
#   'apart'],
#  ['in',
#   'the',
#   'case',
#   'of',
#   'the',
#   'volume',
#   'now',
#   'in',
#   'hand',
#   'the',
#   'reader',
#   'should',
#   'realize',
#   'that',
#   'the',
#   'opening',
#   'chapters',
#   'of',
#   'storm',
#   'of',
#   'swords',
#   'do',
#   'not',
#   'follow',
#   'the',
#   'closing',
#   'chapters',
#   'of',
#   'clash',
#   'of',
#   'kings',
#   'so',
#   'much',
#   'as',
#   'overlap',
#   'them'],
#  ['open',
#   'with',
#   'look',
#   'at',
#   'some',
#   'of',
#   'the',
#   'things',
#   'that',
#   'were',
#   'happening',
#   'on',
#   'the',
#   'fist',
#   'of',
#   'the',
#   'first',
#   'men',
#   'at',
#   'riverrun',
#   'harrenhal',
#   'and',
#   'on',
#   'the',
#   'trident',
#   'while',
#   'thebattleof',
#   'the',
#   'blackwater',
#   'was',
#   'being',
#   'fought',
#   'at',
#   'king',
#   'landing',
#   'and',
#   'during',
#   'its',
#   'aftermath',
#   'george',
#   'martin',
#   'prologue',
#   'the',
#   'day',
#   'was',
#   'grey',
#   'and',
#   'bitter',
#   'cold',
#   'and',
#   'the',
#   'dogs',
#   'would',
#   'not',
#   'take',
#   'the',
#   'scent'],
#  ['the',
#   'big',
#   'black',
#   'bitch',
#   'had',
#   'taken',
#   'one',
#   'sniff',
#   'at',
#   'the',
#   'bear',
#   'tracks',
#   'backed',
#   'off',
#   'and',
#   'skulked',
#   'back',
#   'to',
#   'the',
#   'pack',
#   'page',
#   'with',
#   'her',
#   'tail',
#   'between',
#   'her',
#   'legs'],
#  ['the',
#   'dogs',
#   'huddled',
#   'together',
#   'miserably',
#   'on',
#   'the',
#   'riverbank',
#   'as',
#   'the',
#   'wind',
#   'snapped',
#   'at',
#   'them'],
#  ['chett',
#   'felt',
#   'it',
#   'too',
#   'biting',
#   'through',
#   'his',
#   'layers',
#   'of',
#   'black',
#   'wool',
#   'and',
#   'boiled',
#   'leather'],
#  ['it',
#   'was',
#   'too',
#   'bloody',
#   'cold',
#   'for',
#   'man',
#   'or',
#   'beast',
#   'but',
#   'here',
#   'they',
#   'were'],
#  ['his',
#   'mouth',
#   'twisted',
#   'and',
#   'he',
#   'could',
#   'almost',
#   'feel',
#   'the',
#   'boils',
#   'that',
#   'covered',
#   'his',
#   'cheeks',
#   'and',
#   'neck',
#   'growing',
#   'red',
#   'and',
#   'angry'],
#  ['should',
#   'be',
#   'safe',
#   'back',
#   'at',
#   'the',
#   'wall',
#   'tending',
#   'the',
#   'bloodyravens',
#   'and',
#   'making',
#   'fires',
#   'for',
#   'old',
#   'maesteraemon'],
#  ['it',
#   'was',
#   'the',
#   'bastard',
#   'jon',
#   'snow',
#   'who',
#   'had',
#   'taken',
#   'that',
#   'from',
#   'him',
#   'him',
#   'and',
#   'his',
#   'fat',
#   'friend',
#   'sam',
#   'tarly'],
#  ['it',
#   'was',
#   'their',
#   'fault',
#   'he',
#   'was',
#   'here',
#   'freezing',
#   'his',
#   'bloody',
#   'balls',
#   'off',
#   'with',
#   'pack',
#   'of',
#   'hounds',
#   'deep',
#   'in',
#   'the',
#   'haunted',
#   'forest'],
#  ['seven', 'hells'],
#  ['he',
#   'gave',
#   'the',
#   'leashes',
#   'hard',
#   'yank',
#   'to',
#   'get',
#   'the',
#   'dogs',
#   'attention'],
#  ['track', 'you', 'bastards'],
#  ['that', 'bear', 'print'],
#  ['you', 'want', 'some', 'meat', 'or', 'no'],
#  ['find'],
#  ['but', 'the', 'hounds', 'only', 'huddled', 'closer', 'whining'],
#  ['chett',
#   'snapped',
#   'his',
#   'short',
#   'lash',
#   'above',
#   'their',
#   'heads',
#   'and',
#   'the',
#   'black',
#   'bitch',
#   'snarled',
#   'at',
#   'him'],
#  ['dog',
#   'meat',
#   'would',
#   'taste',
#   'as',
#   'good',
#   'as',
#   'bear',
#   'he',
#   'warned',
#   'her',
#   'his',
#   'breath',
#   'frosting',
#   'with',
#   'every',
#   'word'],
#  ['lark',
#   'the',
#   'sisterman',
#   'stood',
#   'with',
#   'his',
#   'arms',
#   'crossed',
#   'over',
#   'his',
#   'chest',
#   'and',
#   'his',
#   'hands',
#   'tucked',
#   'up',
#   'into',
#   'his',
#   'armpits'],
#  ['he',
#   'wore',
#   'black',
#   'wool',
#   'gloves',
#   'but',
#   'he',
#   'was',
#   'always',
#   'complaining',
#   'how',
#   'his',
#   'fingers',
#   'were',
#   'frozen'],
#  ['it', 'too', 'bloody', 'cold', 'to', 'hunt', 'he', 'said'],
#  ['bugger', 'this', 'bear', 'he', 'not', 'worth', 'freezing', 'over'],
#  ['we',
#   'can',
#   'go',
#   'back',
#   'emptyhand',
#   'lark',
#   'rumbled',
#   'small',
#   'paul',
#   'through',
#   'the',
#   'brown',
#   'whiskers',
#   'that',
#   'covered',
#   'most',
#   'of',
#   'his',
#   'face'],
#  ['the', 'lord', 'commander', 'wouldn', 'like', 'that'],
#  ['there',
#   'was',
#   'ice',
#   'under',
#   'the',
#   'big',
#   'man',
#   'squashed',
#   'pug',
#   'nose',
#   'where',
#   'his',
#   'snot',
#   'had',
#   'frozen'],
#  ['huge',
#   'hand',
#   'in',
#   'thick',
#   'fur',
#   'glove',
#   'clenched',
#   'tight',
#   'around',
#   'the',
#   'shaft',
#   'of',
#   'spear'],
#  ['bugger',
#   'that',
#   'old',
#   'bear',
#   'too',
#   'said',
#   'the',
#   'sisterman',
#   'thin',
#   'man',
#   'with',
#   'sharp',
#   'features',
#   'and',
#   'nervous',
#   'eyes'],
#  ['mormont', 'will', 'be', 'dead', 'before', 'daybreak', 'remember'],
#  ['who', 'cares', 'what', 'he', 'likes'],
#  ['small', 'paul', 'blinked', 'his', 'black', 'little', 'eyes'],
#  ['maybe',
#   'he',
#   'had',
#   'forgotten',
#   'chett',
#   'thought',
#   'he',
#   'was',
#   'stupid',
#   'enough',
#   'to',
#   'forget',
#   'most',
#   'anything'],
#  ['why', 'do', 'we', 'have', 'to', 'kill', 'the', 'old', 'bear'],
#  ['why', 'don', 'we', 'just', 'go', 'off', 'and', 'let', 'him', 'be'],
#  ['you', 'think', 'he', 'll', 'let', 'us', 'be'],
#  ['said', 'lark'],
#  ['he', 'll', 'hunt', 'us', 'down'],
#  ['you', 'want', 'to', 'be', 'hunted', 'you', 'great', 'muttonhead'],
#  ['no', 'said', 'small', 'paul'],
#  ['don', 'want', 'that'],
#  ['don'],
#  ['so', 'you', 'll', 'kill', 'him'],
#  ['said', 'lark'],
#  ['yes'],
#  ['the',
#   'huge',
#   'man',
#   'stamped',
#   'the',
#   'butt',
#   'of',
#   'his',
#   'spear',
#   'on',
#   'the',
#   'frozen',
#   'riverbank'],
#  ['will'],
#  ['he', 'shouldn', 'hunt', 'us'],
#  ['the',
#   'sisterman',
#   'took',
#   'his',
#   'hands',
#   'from',
#   'his',
#   'armpits',
#   'and',
#   'turned',
#   'to',
#   'chett'],
#  ['we', 'need', 'to', 'kill', 'all', 'the', 'officers', 'say'],
#  ['chett', 'was', 'sick', 'of', 'hearing', 'it'],
#  ['we', 'been', 'over', 'this'],
#  ['the', 'old', 'bear', 'dies', 'and', 'blane', 'from', 'theshadowtower'],
#  ['grubbs',
#   'and',
#   'aethan',
#   'as',
#   'well',
#   'their',
#   'ill',
#   'luck',
#   'for',
#   'drawing',
#   'the',
#   'watch',
#   'dywen',
#   'and',
#   'barmen',
#   'for',
#   'their',
#   'tracking',
#   'and',
#   'ser',
#   'piggy',
#   'for',
#   'the',
#   'ravens'],
#  ['that', 'all'],
#  ['we', 'kill', 'them', 'quiet', 'while', 'they', 'sleep'],
#  ['one', 'scream', 'and', 'we', 're', 'wormfood', 'every', 'one', 'of', 'us'],
#  ['his', 'boils', 'were', 'red', 'with', 'rage'],
#  ['just',
#   'do',
#   'your',
#   'bit',
#   'and',
#   'see',
#   'that',
#   'your',
#   'cousins',
#   'do',
#   'theirs'],
#  ['and',
#   'paul',
#   'try',
#   'and',
#   'remember',
#   'it',
#   'third',
#   'watch',
#   'not',
#   'second'],
#  ['third',
#   'watch',
#   'the',
#   'big',
#   'man',
#   'said',
#   'through',
#   'hair',
#   'and',
#   'frozen',
#   'snot'],
#  ['me', 'and', 'softfoot'],
#  ['remember', 'chett'],
#  ['the',
#   'moon',
#   'would',
#   'be',
#   'black',
#   'tonight',
#   'and',
#   'they',
#   'had',
#   'jiggered',
#   'the',
#   'watches',
#   'so',
#   'as',
#   'to',
#   'have',
#   'eight',
#   'of',
#   'their',
#   'own',
#   'standing',
#   'sentry',
#   'with',
#   'two',
#   'more',
#   'guarding',
#   'the',
#   'horses'],
#  ['it', 'wasn', 'going', 'to', 'get', 'much', 'riper', 'than', 'that'],
#  ['besides',
#   'page',
#   'the',
#   'wildlings',
#   'could',
#   'be',
#   'upon',
#   'them',
#   'any',
#   'day',
#   'now'],
#  ['chett',
#   'meant',
#   'to',
#   'be',
#   'well',
#   'away',
#   'from',
#   'here',
#   'before',
#   'that',
#   'happened'],
#  ['he', 'meant', 'to', 'live'],
#  ['three',
#   'hundred',
#   'sworn',
#   'brothers',
#   'of',
#   'the',
#   'night',
#   'watch',
#   'had',
#   'ridden',
#   'north',
#   'two',
#   'hundred',
#   'from',
#   'castle',
#   'black',
#   'and',
#   'another',
#   'hundred',
#   'from',
#   'theshadowtower'],
#  ['it',
#   'was',
#   'the',
#   'biggest',
#   'ranging',
#   'in',
#   'living',
#   'memory',
#   'near',
#   'third',
#   'of',
#   'the',
#   'watch',
#   'strength'],
#  ['they',
#   'meant',
#   'to',
#   'find',
#   'ben',
#   'stark',
#   'ser',
#   'waymar',
#   'royce',
#   'and',
#   'the',
#   'other',
#   'rangers',
#   'who',
#   'gone',
#   'missing',
#   'and',
#   'discover',
#   'why',
#   'the',
#   'wildlings',
#   'were',
#   'leaving',
#   'their',
#   'villages'],
#  ['well',
#   'they',
#   'were',
#   'no',
#   'closer',
#   'to',
#   'stark',
#   'and',
#   'royce',
#   'than',
#   'when',
#   'they',
#   'left',
#   'the',
#   'wall',
#   'but',
#   'they',
#   'learned',
#   'where',
#   'all',
#   'the',
#   'wildlings',
#   'had',
#   'gone',
#   'up',
#   'into',
#   'the',
#   'icy',
#   'heights',
#   'of',
#   'the',
#   'godsforsaken',
#   'frostfangs'],
#  ['they',
#   'could',
#   'squat',
#   'up',
#   'there',
#   'till',
#   'the',
#   'end',
#   'of',
#   'time',
#   'and',
#   'it',
#   'wouldn',
#   'prick',
#   'chett',
#   'boils',
#   'none'],
#  ['but', 'no'],
#  ['they', 'were', 'coming', 'down'],
#  ['down', 'the', 'milkwater'],
#  ['chett', 'raised', 'his', 'eyes', 'and', 'there', 'it', 'was'],
#  ['the',
#   'river',
#   'stony',
#   'banks',
#   'were',
#   'bearded',
#   'by',
#   'ice',
#   'its',
#   'pale',
#   'milky',
#   'waters',
#   'flowing',
#   'endlessly',
#   'down',
#   'out',
#   'of',
#   'the',
#   'frostfangs'],
#  ['and',
#   'now',
#   'mance',
#   'rayder',
#   'and',
#   'his',
#   'wildlings',
#   'were',
#   'flowing',
#   'down',
#   'the',
#   'same',
#   'way'],
#  ['thoren',
#   'smallwood',
#   'had',
#   'returned',
#   'in',
#   'lather',
#   'three',
#   'days',
#   'past'],
#  ['while',
#   'he',
#   'was',
#   'telling',
#   'the',
#   'old',
#   'bear',
#   'what',
#   'his',
#   'scouts',
#   'had',
#   'seen',
#   'his',
#   'man',
#   'kedge',
#   'whiteye',
#   'told',
#   'the',
#   'rest',
#   'of',
#   'them'],
#  ['they',
#   're',
#   'still',
#   'well',
#   'up',
#   'the',
#   'foothills',
#   'but',
#   'they',
#   're',
#   'coming',
#   'kedge',
#   'said',
#   'warming',
#   'his',
#   'hands',
#   'over',
#   'the',
#   'fire'],
#  ['harma', 'the', 'dogshead', 'has', 'the', 'van', 'the', 'poxy', 'bitch'],
#  ['goady',
#   'crept',
#   'up',
#   'on',
#   'her',
#   'camp',
#   'and',
#   'saw',
#   'her',
#   'plain',
#   'by',
#   'the',
#   'fire'],
#  ['that',
#   'fool',
#   'tumberjon',
#   'wanted',
#   'to',
#   'pick',
#   'her',
#   'off',
#   'with',
#   'an',
#   'arrow',
#   'but',
#   'smallwood',
#   'had',
#   'better',
#   'sense'],
#  ['chett', 'spat'],
#  ['how', 'many', 'were', 'there', 'could', 'you', 'tell'],
#  ['many', 'and', 'more'],
#  ['twenty', 'thirty', 'thousand', 'we', 'didn', 'stay', 'to', 'count'],
#  ['harma',
#   'had',
#   'five',
#   'hundred',
#   'in',
#   'the',
#   'van',
#   'every',
#   'one',
#   'ahorse'],
#  ['the', 'men', 'around', 'the', 'fire', 'exchanged', 'uneasy', 'looks'],
#  ['it',
#   'was',
#   'rare',
#   'thing',
#   'to',
#   'find',
#   'even',
#   'dozen',
#   'mounted',
#   'wildlings',
#   'and',
#   'five',
#   'hundred',
#   'smallwood',
#   'sent',
#   'bannen',
#   'and',
#   'me',
#   'wide',
#   'around',
#   'the',
#   'van',
#   'to',
#   'catch',
#   'peek',
#   'at',
#   'the',
#   'main',
#   'body',
#   'kedge',
#   'went',
#   'on'],
#  ['there', 'was', 'no', 'end', 'of', 'them'],
#  ['they',
#   're',
#   'moving',
#   'slow',
#   'as',
#   'frozen',
#   'river',
#   'four',
#   'five',
#   'miles',
#   'day',
#   'but',
#   'they',
#   'don',
#   'look',
#   'like',
#   'they',
#   'mean',
#   'to',
#   'go',
#   'back',
#   'to',
#   'their',
#   'villages',
#   'neither'],
#  ['more',
#   'half',
#   'were',
#   'women',
#   'and',
#   'children',
#   'and',
#   'they',
#   'were',
#   'driving',
#   'their',
#   'animals',
#   'before',
#   'them',
#   'goats',
#   'sheep',
#   'even',
#   'aurochs',
#   'dragging',
#   'sledges'],
#  ['they',
#   'loaded',
#   'up',
#   'with',
#   'bales',
#   'of',
#   'fur',
#   'and',
#   'sides',
#   'of',
#   'meat',
#   'cages',
#   'of',
#   'chickens',
#   'butter',
#   'chums',
#   'and',
#   'spinning',
#   'wheels',
#   'every',
#   'damn',
#   'thing',
#   'they',
#   'own'],
#  ['the',
#   'mules',
#   'and',
#   'garrons',
#   'was',
#   'so',
#   'heavy',
#   'laden',
#   'you',
#   'think',
#   'their',
#   'backs',
#   'would',
#   'break'],
#  ['the', 'women', 'as', 'well'],
#  ['and', 'they', 'follow', 'the', 'milkwater'],
#  ['lark', 'the', 'sisterman', 'asked'],
#  ['said', 'so', 'didn'],
#  ['the',
#   'milkwater',
#   'would',
#   'take',
#   'them',
#   'past',
#   'the',
#   'fist',
#   'of',
#   'the',
#   'first',
#   'men',
#   'the',
#   'ancient',
#   'ringfort',
#   'where',
#   'the',
#   'night',
#   'watch',
#   'had',
#   'made',
#   'its',
#   'camp'],
#  ['any',
#   'man',
#   'with',
#   'thimble',
#   'of',
#   'sense',
#   'could',
#   'see',
#   'that',
#   'it',
#   'was',
#   'time',
#   'to',
#   'pull',
#   'up',
#   'stakes',
#   'and',
#   'fall',
#   'back',
#   'on',
#   'the',
#   'wall'],
#  ['the',
#   'old',
#   'bear',
#   'had',
#   'strengthened',
#   'the',
#   'fist',
#   'with',
#   'spikes',
#   'and',
#   'pits',
#   'and',
#   'caltrops',
#   'but',
#   'against',
#   'such',
#   'host',
#   'all',
#   'that',
#   'was',
#   'pointless'],
#  ['if',
#   'they',
#   'stayed',
#   'here',
#   'they',
#   'would',
#   'be',
#   'engulfed',
#   'and',
#   'overwhelmed'],
#  ['and', 'thoren', 'smallwood', 'wanted', 'to', 'attack'],
#  ['sweet',
#   'donnel',
#   'hill',
#   'was',
#   'squire',
#   'to',
#   'ser',
#   'mallador',
#   'locke',
#   'and',
#   'the',
#   'night',
#   'before',
#   'last',
#   'smallwood',
#   'had',
#   'come',
#   'to',
#   'locke',
#   'tent'],
#  ['ser',
#   'mallador',
#   'had',
#   'been',
#   'of',
#   'the',
#   'same',
#   'mind',
#   'as',
#   'old',
#   'ser',
#   'ottyn',
#   'wythers',
#   'urging',
#   'retreat',
#   'on',
#   'the',
#   'wall',
#   'but',
#   'smallwood',
#   'wanted',
#   'to',
#   'convince',
#   'him',
#   'otherwise'],
#  ['page',
#   'this',
#   'king',
#   'beyond',
#   'the',
#   'wall',
#   'will',
#   'never',
#   'look',
#   'for',
#   'us',
#   'so',
#   'far',
#   'north',
#   'sweet',
#   'donnel',
#   'reported',
#   'him',
#   'saying'],
#  ['and',
#   'this',
#   'great',
#   'host',
#   'of',
#   'his',
#   'is',
#   'shambling',
#   'horde',
#   'full',
#   'of',
#   'useless',
#   'mouths',
#   'who',
#   'won',
#   'know',
#   'what',
#   'end',
#   'of',
#   'sword',
#   'to',
#   'hold'],
#  ['one',
#   'blow',
#   'will',
#   'take',
#   'all',
#   'the',
#   'fight',
#   'out',
#   'of',
#   'them',
#   'and',
#   'send',
#   'them',
#   'howling',
#   'back',
#   'to',
#   'their',
#   'hovels',
#   'for',
#   'another',
#   'fifty',
#   'years'],
#  ['three', 'hundred', 'against', 'thirty', 'thousand'],
#  ['chett',
#   'called',
#   'that',
#   'rank',
#   'madness',
#   'and',
#   'what',
#   'was',
#   'madder',
#   'still',
#   'was',
#   'that',
#   'ser',
#   'mallador',
#   'had',
#   'been',
#   'persuaded',
#   'and',
#   'the',
#   'two',
#   'of',
#   'them',
#   'together',
#   'were',
#   'on',
#   'the',
#   'point',
#   'of',
#   'persuading',
#   'the',
#   'old',
#   'bear'],
#  ['if',
#   'we',
#   'wait',
#   'too',
#   'ion',
#   'this',
#   'chance',
#   'may',
#   'be',
#   'lost',
#   'never',
#   'to',
#   'come',
#   'again',
#   'smallwood',
#   'was',
#   'saying',
#   'to',
#   'anyone',
#   'who',
#   'would',
#   'listen'],
#  ['against',
#   'that',
#   'ser',
#   'ottyn',
#   'wythers',
#   'said',
#   'we',
#   'are',
#   'the',
#   'shield',
#   'that',
#   'guards',
#   'the',
#   'realms',
#   'of',
#   'men'],
#  ['you',
#   'do',
#   'not',
#   'throw',
#   'away',
#   'your',
#   'shield',
#   'for',
#   'no',
#   'good',
#   'purpose',
#   'but',
#   'to',
#   'that',
#   'thoren',
#   'smallwood',
#   'said',
#   'in',
#   'swordfight',
#   'man',
#   'surest',
#   'defense',
#   'is',
#   'the',
#   'swift',
#   'stroke',
#   'that',
#   'slays',
#   'his',
#   'foe',
#   'not',
#   'cringing',
#   'behind',
#   'shield'],
#  ['neither', 'smallwood', 'nor', 'wythers', 'had', 'the', 'command', 'though'],
#  ['lord',
#   'mormont',
#   'did',
#   'and',
#   'mormont',
#   'was',
#   'waiting',
#   'for',
#   'his',
#   'other',
#   'scouts',
#   'for',
#   'jarman',
#   'buckwell',
#   'and',
#   'the',
#   'men',
#   'who',
#   'climbed',
#   'the',
#   'giant',
#   'stair',
#   'and',
#   'for',
#   'qhorin',
#   'halfhand',
#   'and',
#   'jon',
#   'snow',
#   'who',
#   'gone',
#   'to',
#   'probe',
#   'theskirlingpass',
#   'buckwell',
#   'and',
#   'the',
#   'halfhand',
#   'were',
#   'late',
#   'in',
#   'returning',
#   'though'],
#  ['dead', 'most', 'like'],
#  ['chett',
#   'pictured',
#   'jon',
#   'snow',
#   'lying',
#   'blue',
#   'and',
#   'frozen',
#   'on',
#   'some',
#   'bleak',
#   'mountaintop',
#   'with',
#   'wildling',
#   'spear',
#   'up',
#   'his',
#   'bastard',
#   'arse'],
#  ['the', 'thought', 'made', 'him', 'smile'],
#  ['hope', 'they', 'killed', 'his', 'bloody', 'wolf', 'as', 'well'],
#  ['there', 'no', 'bear', 'here', 'he', 'decided', 'abruptly'],
#  ['just', 'an', 'old', 'print', 'that', 'all'],
#  ['back', 'to', 'the', 'fist'],
#  ['the',
#   'dogs',
#   'almost',
#   'yanked',
#   'him',
#   'off',
#   'his',
#   'feet',
#   'as',
#   'eager',
#   'to',
#   'get',
#   'back',
#   'as',
#   'he',
#   'was'],
#  ['maybe', 'they', 'thought', 'they', 'were', 'going', 'to', 'get', 'fed'],
#  ['chett', 'had', 'to', 'laugh'],
#  ['he',
#   'hadn',
#   'fed',
#   'them',
#   'for',
#   'three',
#   'days',
#   'now',
#   'to',
#   'turn',
#   'them',
#   'mean',
#   'and',
#   'hungry'],
#  ['tonight',
#   'before',
#   'slipping',
#   'off',
#   'into',
#   'the',
#   'dark',
#   'he',
#   'turn',
#   'them',
#   'loose',
#   'among',
#   'the',
#   'horse',
#   'lines',
#   'after',
#   'sweet',
#   'donnel',
#   'hill',
#   'and',
#   'clubfoot',
#   'karl',
#   'cut',
#   'the',
#   'tethers'],
#  ['they',
#   'll',
#   'have',
#   'snarling',
#   'hounds',
#   'and',
#   'panicked',
#   'horses',
#   'all',
#   'over',
#   'the',
#   'fist',
#   'running',
#   'through',
#   'fires',
#   'jumping',
#   'the',
#   'ringwall',
#   'and',
#   'trampling',
#   'down',
#   'tents'],
#  ['with',
#   'all',
#   'the',
#   'confusion',
#   'it',
#   'might',
#   'be',
#   'hours',
#   'before',
#   'anyone',
#   'noticed',
#   'that',
#   'fourteen',
#   'brothers',
#   'were',
#   'missing'],
#  ['lark',
#   'had',
#   'wanted',
#   'to',
#   'bring',
#   'in',
#   'twice',
#   'that',
#   'number',
#   'but',
#   'what',
#   'could',
#   'you',
#   'expect',
#   'from',
#   'some',
#   'stupid',
#   'fishbreath',
#   'sisterman'],
#  ['whisper',
#   'word',
#   'in',
#   'the',
#   'wrong',
#   'ear',
#   'and',
#   'before',
#   'you',
#   'knew',
#   'it',
#   'you',
#   'be',
#   'short',
#   'head'],
#  ['no',
#   'fourteen',
#   'was',
#   'good',
#   'number',
#   'enough',
#   'to',
#   'do',
#   'what',
#   'needed',
#   'doing',
#   'but',
#   'not',
#   'so',
#   'many',
#   'that',
#   'they',
#   'couldn',
#   'keep',
#   'the',
#   'secret'],
#  ['chett', 'had', 'recruited', 'most', 'of', 'them', 'himself'],
#  ['small',
#   'paul',
#   'was',
#   'one',
#   'of',
#   'his',
#   'the',
#   'strongest',
#   'man',
#   'on',
#   'the',
#   'wall',
#   'even',
#   'if',
#   'he',
#   'was',
#   'slower',
#   'than',
#   'dead',
#   'snail'],
#  ['he', 'once', 'broken', 'wildling', 'back', 'with', 'hug'],
#  ['they',
#   'had',
#   'dirk',
#   'as',
#   'well',
#   'named',
#   'for',
#   'his',
#   'favorite',
#   'weapon',
#   'and',
#   'the',
#   'little',
#   'grey',
#   'man',
#   'the',
#   'brothers',
#   'called',
#   'softfoot',
#   'who',
#   'raped',
#   'hundred',
#   'women',
#   'in',
#   'his',
#   'youth',
#   'and',
#   'liked',
#   'to',
#   'boast',
#   'how',
#   'none',
#   'had',
#   'never',
#   'seen',
#   'nor',
#   'heard',
#   'him',
#   'until',
#   'he',
#   'shoved',
#   'it',
#   'up',
#   'inside',
#   'them'],
#  ['the', 'plan', 'was', 'chett'],
#  ['he',
#   'was',
#   'the',
#   'clever',
#   'one',
#   'he',
#   'been',
#   'steward',
#   'to',
#   'old',
#   'maester',
#   'aemon',
#   'for',
#   'four',
#   'good',
#   'years',
#   'before',
#   'that',
#   'bastard',
#   'jon',
#   'snow',
#   'had',
#   'done',
#   'him',
#   'out',
#   'so',
#   'his',
#   'job',
#   'could',
#   'be',
#   'handed',
#   'to',
#   'his',
#   'fat',
#   'pig',
#   'of',
#   'friend'],
#  ['when',
#   'he',
#   'killed',
#   'sam',
#   'tarly',
#   'tonight',
#   'he',
#   'planned',
#   'to',
#   'whisper',
#   'give',
#   'my',
#   'love',
#   'to',
#   'lord',
#   'snow',
#   'right',
#   'in',
#   'his',
#   'ear',
#   'before',
#   'he',
#   'sliced',
#   'ser',
#   'piggy',
#   'throat',
#   'open',
#   'to',
#   'let',
#   'the',
#   'blood',
#   'come',
#   'bubbling',
#   'out',
#   'through',
#   'all',
#   'those',
#   'layers',
#   'of',
#   'suet'],
#  ['chett',
#   'knew',
#   'the',
#   'ravens',
#   'so',
#   'he',
#   'wouldn',
#   'have',
#   'no',
#   'trouble',
#   'there',
#   'no',
#   'more',
#   'than',
#   'he',
#   'would',
#   'with',
#   'tarly'],
#  ['one',
#   'touch',
#   'of',
#   'the',
#   'knife',
#   'and',
#   'that',
#   'craven',
#   'would',
#   'piss',
#   'his',
#   'pants',
#   'and',
#   'start',
#   'blubbering',
#   'for',
#   'his',
#   'life'],
#  ['let', 'him', 'beg', 'it', 'won', 'do', 'him', 'no', 'good'],
#  ['after',
#   'he',
#   'opened',
#   'his',
#   'throat',
#   'he',
#   'open',
#   'the',
#   'cages',
#   'and',
#   'shoo',
#   'the',
#   'birds',
#   'away',
#   'so',
#   'no',
#   'messages',
#   'reached',
#   'the',
#   'wall'],
#  ['softfoot',
#   'and',
#   'small',
#   'paul',
#   'would',
#   'kill',
#   'the',
#   'old',
#   'bear',
#   'dirk',
#   'would',
#   'do',
#   'blane',
#   'and',
#   'lark',
#   'and',
#   'his',
#   'cousins',
#   'would',
#   'silence',
#   'bannen',
#   'and',
#   'old',
#   'dywen',
#   'to',
#   'keep',
#   'them',
#   'from',
#   'sniffing',
#   'after',
#   'their',
#   'trail'],
#  ['they',
#   'been',
#   'caching',
#   'food',
#   'for',
#   'fortnight',
#   'and',
#   'sweet',
#   'donnel',
#   'and',
#   'clubfoot',
#   'karl',
#   'would',
#   'have',
#   'the',
#   'horses',
#   'ready'],
#  ['with',
#   'mormont',
#   'dead',
#   'command',
#   'would',
#   'pass',
#   'to',
#   'ser',
#   'ottyn',
#   'wythers',
#   'an',
#   'old',
#   'done',
#   'man',
#   'and',
#   'failing'],
#  ['he',
#   'll',
#   'be',
#   'running',
#   'for',
#   'the',
#   'wall',
#   'page',
#   'before',
#   'sundown',
#   'and',
#   'he',
#   'won',
#   'waste',
#   'no',
#   'men',
#   'sending',
#   'them',
#   'after',
#   'us',
#   'neither'],
#  ['the',
#   'dogs',
#   'pulled',
#   'at',
#   'him',
#   'as',
#   'they',
#   'made',
#   'their',
#   'way',
#   'through',
#   'the',
#   'trees'],
#  ['chett',
#   'could',
#   'see',
#   'the',
#   'fist',
#   'punching',
#   'its',
#   'way',
#   'up',
#   'through',
#   'the',
#   'green'],
#  ['the',
#   'day',
#   'was',
#   'so',
#   'dark',
#   'that',
#   'the',
#   'old',
#   'bear',
#   'had',
#   'the',
#   'torches',
#   'lit',
#   'great',
#   'circle',
#   'of',
#   'them',
#   'burning',
#   'all',
#   'along',
#   'the',
#   'ringwall',
#   'that',
#   'crowned',
#   'the',
#   'top',
#   'of',
#   'the',
#   'steep',
#   'stony',
#   'hill'],
#  ['the', 'three', 'of', 'them', 'waded', 'across', 'brook'],
#  ['the',
#   'water',
#   'was',
#   'icy',
#   'cold',
#   'and',
#   'patches',
#   'of',
#   'ice',
#   'were',
#   'spreading',
#   'across',
#   'its',
#   'surface'],
#  ['going',
#   'to',
#   'make',
#   'for',
#   'the',
#   'coast',
#   'lark',
#   'the',
#   'sisterman',
#   'confided'],
#  ['me', 'and', 'my', 'cousins'],
#  ['we',
#   'll',
#   'build',
#   'us',
#   'boat',
#   'sail',
#   'back',
#   'home',
#   'to',
#   'the',
#   'sisters'],
#  ['and',
#   'at',
#   'home',
#   'they',
#   'll',
#   'know',
#   'you',
#   'for',
#   'deserters',
#   'and',
#   'lop',
#   'off',
#   'your',
#   'fool',
#   'heads',
#   'thought',
#   'chett'],
#  ['there',
#   'was',
#   'no',
#   'leaving',
#   'the',
#   'night',
#   'watch',
#   'once',
#   'you',
#   'said',
#   'your',
#   'words'],
#  ['anywhere',
#   'in',
#   'the',
#   'seven',
#   'kingdoms',
#   'they',
#   'take',
#   'you',
#   'and',
#   'kill',
#   'you'],
#  ['ollo',
#   'lophand',
#   'now',
#   'he',
#   'was',
#   'talking',
#   'about',
#   'sailing',
#   'back',
#   'to',
#   'tyrosh',
#   'where',
#   'he',
#   'claimed',
#   'men',
#   'didn',
#   'lose',
#   'their',
#   'hands',
#   'for',
#   'bit',
#   'of',
#   'honest',
#   'thievery',
#   'nor',
#   'get',
#   'sent',
#   'off',
#   'to',
#   'freeze',
#   'their',
#   'life',
#   'away',
#   'for',
#   'being',
#   'found',
#   'in',
#   'bed',
#   'with',
#   'some',
#   'knight',
#   'wife'],
#  ['chett',
#   'had',
#   'weighed',
#   'going',
#   'with',
#   'him',
#   'but',
#   'he',
#   'didn',
#   'speak',
#   'their',
#   'wet',
#   'girly',
#   'tongue'],
#  ['and', 'what', 'could', 'he', 'do', 'in', 'tyrosh'],
#  ['he',
#   'had',
#   'no',
#   'trade',
#   'to',
#   'speak',
#   'of',
#   'growing',
#   'up',
#   'in',
#   'hag',
#   'mire'],
#  ['his',
#   'father',
#   'had',
#   'spent',
#   'his',
#   'life',
#   'grubbing',
#   'in',
#   'other',
#   'men',
#   'fields',
#   'and',
#   'collecting',
#   'leeches'],
#  ['he',
#   'strip',
#   'down',
#   'bare',
#   'but',
#   'for',
#   'thick',
#   'leather',
#   'clout',
#   'and',
#   'go',
#   'wading',
#   'in',
#   'the',
#   'murky',
#   'waters'],
#  ['when',
#   'he',
#   'climbed',
#   'out',
#   'he',
#   'be',
#   'covered',
#   'from',
#   'nipple',
#   'to',
#   'ankle'],
#  ['sometimes', 'he', 'made', 'chett', 'help', 'pull', 'the', 'leeches', 'off'],
#  ['one',
#   'had',
#   'attached',
#   'itself',
#   'to',
#   'his',
#   'palm',
#   'once',
#   'and',
#   'he',
#   'smashed',
#   'it',
#   'against',
#   'wall',
#   'in',
#   'revulsion'],
#  ['his', 'father', 'beat', 'him', 'bloody', 'for', 'that'],
#  ['the',
#   'maesters',
#   'bought',
#   'the',
#   'leeches',
#   'at',
#   'twelve',
#   'for',
#   'apenny'],
#  ['lark',
#   'could',
#   'go',
#   'home',
#   'if',
#   'he',
#   'liked',
#   'and',
#   'the',
#   'damn',
#   'tyroshi',
#   'too',
#   'but',
#   'not',
#   'chett'],
#  ['if',
#   'he',
#   'never',
#   'saw',
#   'hag',
#   'mire',
#   'again',
#   'it',
#   'would',
#   'be',
#   'too',
#   'bloody',
#   'soon'],
#  ['he', 'had', 'liked', 'the', 'look', 'of', 'craster', 'keep', 'himself'],
#  ['craster',
#   'lived',
#   'high',
#   'as',
#   'lord',
#   'there',
#   'so',
#   'why',
#   'shouldn',
#   'he',
#   'do',
#   'the',
#   'same'],
#  ['that', 'would', 'be', 'laugh'],
#  ['chett', 'the', 'leechman', 'son', 'lord', 'with', 'keep'],
#  ['his',
#   'banner',
#   'could',
#   'be',
#   'dozen',
#   'leeches',
#   'on',
#   'field',
#   'of',
#   'pink'],
#  ['but', 'why', 'stop', 'at', 'lord'],
#  ['maybe', 'he', 'should', 'be', 'king'],
#  ['mance', 'rayder', 'started', 'out', 'crow'],
#  ['could',
#   'be',
#   'king',
#   'same',
#   'as',
#   'him',
#   'and',
#   'have',
#   'me',
#   'some',
#   'wives'],
#  ['craster',
#   'had',
#   'nineteen',
#   'not',
#   'even',
#   'counting',
#   'the',
#   'young',
#   'ones',
#   'the',
#   'daughters',
#   'he',
#   'hadn',
#   'gotten',
#   'around',
#   'to',
#   'bedding',
#   'yet'],
#  ['half',
#   'them',
#   'wives',
#   'were',
#   'as',
#   'old',
#   'and',
#   'ugly',
#   'as',
#   'craster',
#   'but',
#   'that',
#   'didn',
#   'matter'],
#  ['the',
#   'old',
#   'ones',
#   'chett',
#   'could',
#   'put',
#   'to',
#   'work',
#   'cooking',
#   'and',
#   'cleaning',
#   'for',
#   'him',
#   'pulling',
#   'carrots',
#   'and',
#   'slopping',
#   'pigs',
#   'while',
#   'the',
#   'young',
#   'ones',
#   'warmed',
#   'his',
#   'bed',
#   'and',
#   'bore',
#   'his',
#   'children'],
#  ['craster',
#   'wouldn',
#   'object',
#   'not',
#   'once',
#   'small',
#   'paul',
#   'gave',
#   'him',
#   'hug'],
#  ['the',
#   'only',
#   'women',
#   'chett',
#   'had',
#   'ever',
#   'known',
#   'were',
#   'the',
#   'whores',
#   'he',
#   'bought',
#   'in',
#   'mole',
#   'town'],
#  ['when',
#   'he',
#   'been',
#   'younger',
#   'the',
#   'village',
#   'girls',
#   'took',
#   'one',
#   'look',
#   'at',
#   'his',
#   'face',
#   'with',
#   'its',
#   'boils',
#   'and',
#   'its',
#   'wen',
#   'and',
#   'turned',
#   'away',
#   'sickened'],
#  ['the', 'worst', 'was', 'that', 'slattern', 'bessa'],
#  ['she',
#   'spread',
#   'her',
#   'legs',
#   'for',
#   'every',
#   'boy',
#   'in',
#   'hag',
#   'mire',
#   'so',
#   'he',
#   'figured',
#   'why',
#   'not',
#   'him',
#   'too'],
#  ['he',
#   'even',
#   'spent',
#   'morning',
#   'picking',
#   'wildflowers',
#   'when',
#   'he',
#   'heard',
#   'she',
#   'liked',
#   'them',
#   'but',
#   'she',
#   'just',
#   'laughed',
#   'in',
#   'his',
#   'face',
#   'and',
#   'told',
#   'him',
#   'she',
#   'crawl',
#   'in',
#   'bed',
#   'with',
#   'his',
#   'father',
#   'leeches',
#   'before',
#   'she',
#   'crawl',
#   'in',
#   'one',
#   'with',
#   'him'],
#  ['she',
#   'stopped',
#   'laughing',
#   'when',
#   'he',
#   'put',
#   'his',
#   'knife',
#   'in',
#   'her'],
#  ['that',
#   'was',
#   'sweet',
#   'the',
#   'look',
#   'on',
#   'her',
#   'face',
#   'so',
#   'he',
#   'pulled',
#   'the',
#   'knife',
#   'out',
#   'and',
#   'put',
#   'it',
#   'in',
#   'her',
#   'again'],
#  ['when',
#   'they',
#   'caught',
#   'him',
#   'down',
#   'near',
#   'sevenstrearns',
#   'old',
#   'lord',
#   'walder',
#   'frey',
#   'hadn',
#   'even',
#   'bothered',
#   'to',
#   'come',
#   'himself',
#   'to',
#   'do',
#   'the',
#   'judging'],
#  ['he',
#   'sent',
#   'one',
#   'of',
#   'his',
#   'bastards',
#   'that',
#   'walder',
#   'rivers',
#   'and',
#   'the',
#   'next',
#   'thing',
#   'chett',
#   'had',
#   'known',
#   'he',
#   'was',
#   'walking',
#   'to',
#   'the',
#   'wall',
#   'with',
#   'that',
#   'foulsmelling',
#   'black',
#   'devil',
#   'yoren'],
#  ['to',
#   'pay',
#   'for',
#   'his',
#   'one',
#   'sweet',
#   'moment',
#   'they',
#   'took',
#   'his',
#   'whole',
#   'life'],
#  ['but',
#   'now',
#   'he',
#   'meant',
#   'to',
#   'take',
#   'it',
#   'back',
#   'and',
#   'craster',
#   'women',
#   'too'],
#  ['that', 'twisted', 'old', 'wildling', 'has', 'the', 'right', 'of', 'it'],
#  ['if',
#   'you',
#   'want',
#   'woman',
#   'to',
#   'wife',
#   'you',
#   'take',
#   'her',
#   'and',
#   'none',
#   'of',
#   'this',
#   'giving',
#   'her',
#   'flowers',
#   'so',
#   'that',
#   'maybe',
#   'she',
#   'don',
#   'notice',
#   'your',
#   'bloody',
#   'boils'],
#  ['chett', 'didn', 'mean', 'to', 'make', 'that', 'mistake', 'again'],
#  ['it',
#   'would',
#   'work',
#   'he',
#   'promised',
#   'himself',
#   'for',
#   'the',
#   'hundredth',
#   'time'],
#  ['so', 'long', 'as', 'we', 'get', 'away', 'clean'],
#  ['ser',
#   'ottyn',
#   'page',
#   'would',
#   'strike',
#   'south',
#   'for',
#   'the',
#   'shadow',
#   'tower',
#   'the',
#   'shortest',
#   'way',
#   'to',
#   'the',
#   'wall'],
#  ['he',
#   'won',
#   'bother',
#   'with',
#   'us',
#   'not',
#   'wythers',
#   'all',
#   'he',
#   'll',
#   'want',
#   'is',
#   'to',
#   'get',
#   'back',
#   'whole'],
#  ['thoren',
#   'smallwood',
#   'now',
#   'he',
#   'want',
#   'to',
#   'press',
#   'on',
#   'with',
#   'the',
#   'attack',
#   'but',
#   'ser',
#   'ottyn',
#   'caution',
#   'ran',
#   'too',
#   'deep',
#   'and',
#   'he',
#   'was',
#   'senior'],
#  ['it',
#   'won',
#   'matter',
#   'anyhow',
#   'once',
#   'we',
#   're',
#   'gone',
#   'smallwood',
#   'can',
#   'attack',
#   'anyone',
#   'he',
#   'likes'],
#  ['what', 'do', 'we', 'care'],
#  ['if',
#   'none',
#   'of',
#   'them',
#   'ever',
#   'returns',
#   'to',
#   'the',
#   'wall',
#   'no',
#   'one',
#   'will',
#   'ever',
#   'come',
#   'looking',
#   'for',
#   'us',
#   'they',
#   'll',
#   'think',
#   'we',
#   'died',
#   'with',
#   'the',
#   'rest'],
#  ['that',
#   'was',
#   'new',
#   'thought',
#   'and',
#   'for',
#   'moment',
#   'it',
#   'tempted',
#   'him'],
#  ['but',
#   'they',
#   'would',
#   'need',
#   'to',
#   'kill',
#   'ser',
#   'ottyn',
#   'and',
#   'ser',
#   'mallador',
#   'locke',
#   'as',
#   'well',
#   'to',
#   'give',
#   'smallwood',
#   'the',
#   'command',
#   'and',
#   'both',
#   'of',
#   'them',
#   'were',
#   'well',
#   'attended',
#   'day',
#   'and',
#   'night',
#   'no',
#   'the',
#   'risk',
#   'was',
#   'too',
#   'great'],
#  ['chett',
#   'said',
#   'small',
#   'paul',
#   'as',
#   'they',
#   'trudged',
#   'along',
#   'stony',
#   'game',
#   'trail',
#   'through',
#   'sentinels',
#   'and',
#   'soldier',
#   'pines',
#   'what',
#   'about',
#   'the',
#   'bird'],
#  ['what', 'bloody', 'bird'],
#  ['the',
#   'last',
#   'thing',
#   'he',
#   'needed',
#   'now',
#   'was',
#   'some',
#   'muttonhead',
#   'going',
#   'on',
#   'about',
#   'bird'],
#  ['the', 'old', 'bear', 'raven', 'small', 'paul', 'said'],
#  ['if', 'we', 'kill', 'him', 'who', 'going', 'to', 'feed', 'his', 'bird'],
#  ['who', 'bloody', 'well', 'cares'],
#  ['kill', 'the', 'bird', 'too', 'if', 'you', 'like'],
#  ['don', 'want', 'to', 'hurt', 'no', 'bird', 'the', 'big', 'man', 'said'],
#  ['but', 'that', 'talking', 'bird'],
#  ['what', 'if', 'it', 'tells', 'what', 'we', 'did'],
#  ['lark', 'the', 'sisterman', 'laughed'],
#  ['small', 'paul', 'thick', 'as', 'castle', 'wall', 'he', 'mocked'],
#  ['you', 'shut', 'up', 'with', 'that', 'said', 'small', 'paul', 'dangerously'],
#  ['paul',
#   'said',
#   'chett',
#   'before',
#   'the',
#   'big',
#   'man',
#   'got',
#   'too',
#   'angry',
#   'when',
#   'they',
#   'find',
#   'the',
#   'old',
#   'man',
#   'lying',
#   'in',
#   'pool',
#   'of',
#   'blood',
#   'with',
#   'his',
#   'throat',
#   'slit',
#   'they',
#   'won',
#   'need',
#   'no',
#   'bird',
#   'to',
#   'tell',
#   'them',
#   'someone',
#   'killed',
#   'him'],
#  ['small', 'paul', 'chewed', 'on', 'that', 'moment'],
#  ['that', 'true', 'he', 'allowed'],
#  ['can', 'keep', 'the', 'bird', 'then'],
#  ['like', 'that', 'bird'],
#  ['he', 'yours', 'said', 'chett', 'just', 'to', 'shut', 'him', 'up'],
#  ['we',
#   'can',
#   'always',
#   'eat',
#   'him',
#   'if',
#   'we',
#   'get',
#   'hungry',
#   'offered',
#   'lark'],
#  ['small', 'paul', 'clouded', 'up', 'again'],
#  ['best', 'not', 'try', 'and', 'eat', 'my', 'bird', 'lark'],
#  ['best', 'not'],
#  ['chett', 'could', 'hear', 'voices', 'drifting', 'through', 'the', 'trees'],
#  ['close', 'your', 'bloody', 'mouths', 'both', 'of', 'you'],
#  ['we', 're', 'almost', 'to', 'the', 'fist'],
#  ['they',
#   'emerged',
#   'near',
#   'the',
#   'west',
#   'face',
#   'of',
#   'the',
#   'hill',
#   'and',
#   'walked',
#   'around',
#   'south',
#   'where',
#   'the',
#   'slope',
#   'was',
#   'gentler'],
#  ['near',
#   'the',
#   'edge',
#   'of',
#   'the',
#   'forest',
#   'dozen',
#   'men',
#   'were',
#   'taking',
#   'archery',
#   'practice'],
#  ['they',
#   'had',
#   'carved',
#   'outlines',
#   'on',
#   'the',
#   'trunks',
#   'of',
#   'trees',
#   'and',
#   'were',
#   'loosing',
#   'shafts',
#   'at',
#   'them'],
#  ['look', 'said', 'lark'],
#  ['pig', 'with', 'bow'],
#  ['sure',
#   'enough',
#   'the',
#   'nearest',
#   'bowman',
#   'was',
#   'ser',
#   'piggy',
#   'himself',
#   'the',
#   'fat',
#   'boy',
#   'who',
#   'had',
#   'stolen',
#   'his',
#   'place',
#   'with',
#   'maester',
#   'aemon'],
#  ['just',
#   'the',
#   'sight',
#   'of',
#   'samwell',
#   'tarly',
#   'filled',
#   'him',
#   'with',
#   'anger'],
#  ['stewarding',
#   'for',
#   'maester',
#   'aemon',
#   'had',
#   'been',
#   'as',
#   'good',
#   'life',
#   'as',
#   'he',
#   'ever',
#   'known'],
#  ['the',
#   'old',
#   'blind',
#   'man',
#   'was',
#   'undemanding',
#   'and',
#   'clydas',
#   'had',
#   'taken',
#   'care',
#   'of',
#   'most',
#   'of',
#   'his',
#   'wants',
#   'anyway'],
#  ['chett',
#   'duties',
#   'were',
#   'easy',
#   'cleaning',
#   'the',
#   'rookery',
#   'few',
#   'fires',
#   'to',
#   'build',
#   'few',
#   'meals',
#   'to',
#   'fetch',
#   'and',
#   'aemon',
#   'never',
#   'once',
#   'hit',
#   'him'],
#  ['thinks',
#   'he',
#   'can',
#   'just',
#   'walk',
#   'in',
#   'and',
#   'shove',
#   'me',
#   'out',
#   'on',
#   'account',
#   'of',
#   'being',
#   'highborn',
#   'and',
#   'knowing',
#   'how',
#   'to',
#   'read'],
#  ['might',
#   'be',
#   'it',
#   'ask',
#   'him',
#   'to',
#   'read',
#   'my',
#   'knife',
#   'before',
#   'open',
#   'his',
#   'throat',
#   'with',
#   'it'],
#  ['you',
#   'go',
#   'on',
#   'he',
#   'told',
#   'the',
#   'others',
#   'want',
#   'to',
#   'watch',
#   'this'],
#  ['the',
#   'dogs',
#   'were',
#   'pulling',
#   'anxious',
#   'to',
#   'go',
#   'with',
#   'them',
#   'to',
#   'the',
#   'food',
#   'they',
#   'thought',
#   'would',
#   'be',
#   'waiting',
#   'at',
#   'the',
#   'top'],
#  ['chett',
#   'kicked',
#   'the',
#   'bitch',
#   'with',
#   'the',
#   'toe',
#   'page',
#   'of',
#   'his',
#   'boot',
#   'and',
#   'that',
#   'settled',
#   'them',
#   'down',
#   'some'],
#  ['he',
#   'watched',
#   'from',
#   'the',
#   'trees',
#   'as',
#   'the',
#   'fat',
#   'boy',
#   'wrestled',
#   'with',
#   'longbow',
#   'as',
#   'tall',
#   'as',
#   'he',
#   'was',
#   'his',
#   'red',
#   'moon',
#   'face',
#   'screwed',
#   'up',
#   'with',
#   'concentration'],
#  ['three', 'arrows', 'stood', 'in', 'the', 'ground', 'before', 'him'],
#  ['tarly',
#   'nocked',
#   'and',
#   'drew',
#   'held',
#   'the',
#   'draw',
#   'long',
#   'moment',
#   'as',
#   'he',
#   'tried',
#   'to',
#   'aim',
#   'and',
#   'let',
#   'fly'],
#  ['the', 'shaft', 'vanished', 'into', 'the', 'greenery'],
#  ['chett', 'laughed', 'loudly', 'snort', 'of', 'sweet', 'disgust'],
#  ['we',
#   'll',
#   'never',
#   'find',
#   'that',
#   'one',
#   'and',
#   'll',
#   'be',
#   'blamed',
#   'announced',
#   'edd',
#   'tollett',
#   'the',
#   'dour',
#   'grey',
#   'haired',
#   'squire',
#   'everyone',
#   'called',
#   'dolorous',
#   'edd'],
#  ['nothing',
#   'ever',
#   'goes',
#   'missing',
#   'that',
#   'they',
#   'don',
#   'look',
#   'at',
#   'me',
#   'ever',
#   'since',
#   'that',
#   'time',
#   'lost',
#   'my',
#   'horse'],
#  ['as', 'if', 'that', 'could', 'be', 'helped'],
#  ['he',
#   'was',
#   'white',
#   'and',
#   'it',
#   'was',
#   'snowing',
#   'what',
#   'did',
#   'they',
#   'expect'],
#  ['the',
#   'wind',
#   'took',
#   'that',
#   'one',
#   'said',
#   'grenn',
#   'another',
#   'friend',
#   'of',
#   'lord',
#   'snow'],
#  ['try', 'to', 'hold', 'the', 'bow', 'steady', 'sam'],
#  ['it',
#   'heavy',
#   'the',
#   'fat',
#   'boy',
#   'complained',
#   'but',
#   'he',
#   'pulled',
#   'the',
#   'second',
#   'arrow',
#   'all',
#   'the',
#   'same'],
#  ['this',
#   'one',
#   'went',
#   'high',
#   'sailing',
#   'through',
#   'the',
#   'branches',
#   'ten',
#   'feet',
#   'above',
#   'the',
#   'target'],
#  ['believe',
#   'you',
#   'knocked',
#   'leaf',
#   'off',
#   'that',
#   'tree',
#   'said',
#   'dolorous',
#   'edd'],
#  ['fall',
#   'is',
#   'falling',
#   'fast',
#   'enough',
#   'there',
#   'no',
#   'need',
#   'to',
#   'help',
#   'it'],
#  ['he', 'sighed'],
#  ['and', 'we', 'all', 'know', 'what', 'follows', 'fall'],
#  ['gods', 'but', 'am', 'cold'],
#  ['shoot',
#   'the',
#   'last',
#   'arrow',
#   'samwell',
#   'believe',
#   'my',
#   'tongue',
#   'is',
#   'freezing',
#   'to',
#   'the',
#   'roof',
#   'of',
#   'my',
#   'mouth'],
#  ['ser',
#   'piggy',
#   'lowered',
#   'the',
#   'bow',
#   'and',
#   'chett',
#   'thought',
#   'he',
#   'was',
#   'going',
#   'to',
#   'start',
#   'bawling'],
#  ['it', 'too', 'hard'],
#  ['notch', 'draw', 'and', 'loose', 'said', 'grenn'],
#  ['go', 'on'],
#  ['dutifully',
#   'the',
#   'fat',
#   'boy',
#   'plucked',
#   'his',
#   'final',
#   'arrow',
#   'from',
#   'the',
#   'earth',
#   'notched',
#   'it',
#   'to',
#   'his',
#   'longbow',
#   'drew',
#   'and',
#   'released'],
#  ['he',
#   'did',
#   'it',
#   'quickly',
#   'without',
#   'squinting',
#   'along',
#   'the',
#   'shaft',
#   'painstakingly',
#   'as',
#   'he',
#   'had',
#   'the',
#   'first',
#   'two',
#   'times'],
#  ['the',
#   'arrow',
#   'struck',
#   'the',
#   'charcoal',
#   'outline',
#   'low',
#   'in',
#   'the',
#   'chest',
#   'and',
#   'hung',
#   'quivering'],
#  ['hit', 'him'],
#  ['ser', 'piggy', 'sounded', 'shocked'],
#  ['grenn', 'did', 'you', 'see'],
#  ['edd', 'look', 'hit', 'him'],
#  ['put', 'it', 'between', 'his', 'ribs', 'id', 'say', 'said', 'grenn'],
#  ['did', 'kill', 'him'],
#  ['the', 'fat', 'boy', 'wanted', 'to', 'know'],
#  ['tollett', 'shrugged'],
#  ['might', 'have', 'punctured', 'lung', 'if', 'he', 'had', 'lung'],
#  ['most', 'trees', 'don', 'as', 'rule'],
#  ['he', 'took', 'the', 'bow', 'from', 'sam', 'hand'],
#  ['ve', 'seen', 'worse', 'shots', 'though'],
#  ['aye', 'and', 'made', 'few'],
#  ['ser', 'piggy', 'was', 'beaming'],
#  ['to',
#   'look',
#   'at',
#   'him',
#   'you',
#   'think',
#   'he',
#   'actually',
#   'done',
#   'something'],
#  ['but',
#   'when',
#   'he',
#   'saw',
#   'chett',
#   'and',
#   'the',
#   'dogs',
#   'his',
#   'smile',
#   'curled',
#   'up',
#   'and',
#   'died',
#   'squeaking'],
#  ['you', 'hit', 'tree', 'chett', 'said'],
#  ['let',
#   'see',
#   'how',
#   'you',
#   'shoot',
#   'when',
#   'it',
#   'mance',
#   'rayder',
#   'lads'],
#  ['they',
#   'won',
#   'stand',
#   'there',
#   'with',
#   'their',
#   'arms',
#   'out',
#   'and',
#   'their',
#   'leaves',
#   'rustling',
#   'oh',
#   'no'],
#  ['they',
#   'll',
#   'come',
#   'right',
#   'at',
#   'you',
#   'screaming',
#   'in',
#   'your',
#   'face',
#   'and',
#   'bet',
#   'you',
#   'll',
#   'piss',
#   'those',
#   'breeches'],
#  ['one',
#   'them',
#   'will',
#   'plant',
#   'his',
#   'axe',
#   'right',
#   'between',
#   'those',
#   'little',
#   'pig',
#   'eyes'],
#  ['the',
#   'last',
#   'thing',
#   'you',
#   'll',
#   'hear',
#   'will',
#   'be',
#   'the',
#   'thunk',
#   'it',
#   'makes',
#   'when',
#   'it',
#   'bites',
#   'into',
#   'your',
#   'skull'],
#  ['the', 'fat', 'boy', 'was', 'shaking'],
#  ['dolorous', 'edd', 'put', 'hand', 'on', 'his', 'shoulder'],
#  ['brother',
#   'he',
#   'said',
#   'solemnly',
#   'just',
#   'because',
#   'it',
#   'happened',
#   'that',
#   'way',
#   'for',
#   'you',
#   'doesn',
#   'mean',
#   'samwell',
#   'will',
#   'suffer',
#   'the',
#   'same'],
#  ['what', 'are', 'you', 'talking', 'about', 'tollett'],
#  ['page', 'the', 'axe', 'that', 'split', 'your', 'skull'],
#  ['is',
#   'it',
#   'true',
#   'that',
#   'half',
#   'your',
#   'wits',
#   'leaked',
#   'out',
#   'on',
#   'the',
#   'ground',
#   'and',
#   'your',
#   'dogs',
#   'ate',
#   'them'],
#  ['the',
#   'big',
#   'lout',
#   'grenn',
#   'laughed',
#   'and',
#   'even',
#   'samwell',
#   'tarly',
#   'managed',
#   'weak',
#   'little',
#   'smile'],
#  ['chett',
#   'kicked',
#   'the',
#   'nearest',
#   'dog',
#   'yanked',
#   'on',
#   'their',
#   'leashes',
#   'and',
#   'started',
#   'up',
#   'the',
#   'hill'],
#  ['smile', 'all', 'you', 'want', 'ser', 'piggy'],
#  ['we', 'll', 'see', 'who', 'laughs', 'tonight'],
#  ['he',
#   'only',
#   'wished',
#   'he',
#   'had',
#   'time',
#   'to',
#   'kill',
#   'tollett',
#   'as',
#   'well'],
#  ['gloomy', 'horsefaced', 'fool', 'that', 'what', 'he', 'is'],
#  ['the',
#   'climb',
#   'was',
#   'steep',
#   'even',
#   'on',
#   'this',
#   'side',
#   'of',
#   'the',
#   'fist',
#   'which',
#   'had',
#   'the',
#   'gentlest',
#   'slope'],
#  ['partway',
#   'up',
#   'the',
#   'dogs',
#   'started',
#   'barking',
#   'and',
#   'pulling',
#   'at',
#   'him',
#   'figuring',
#   'that',
#   'they',
#   'get',
#   'fed',
#   'soon'],
#  ['he',
#   'gave',
#   'them',
#   'taste',
#   'of',
#   'his',
#   'boot',
#   'instead',
#   'and',
#   'crack',
#   'of',
#   'the',
#   'whip',
#   'for',
#   'the',
#   'big',
#   'ugly',
#   'one',
#   'that',
#   'snapped',
#   'at',
#   'him'],
#  ['once', 'they', 'were', 'tied', 'up', 'he', 'went', 'to', 'report'],
#  ['the',
#   'prints',
#   'were',
#   'there',
#   'like',
#   'giant',
#   'said',
#   'but',
#   'the',
#   'dogs',
#   'wouldn',
#   'track',
#   'he',
#   'told',
#   'mormont',
#   'in',
#   'front',
#   'of',
#   'his',
#   'big',
#   'black',
#   'tent'],
#  ['down',
#   'by',
#   'the',
#   'river',
#   'like',
#   'that',
#   'could',
#   'be',
#   'old',
#   'prints'],
#  ['pity'],
#  ['lord',
#   'commander',
#   'mormont',
#   'had',
#   'bald',
#   'head',
#   'and',
#   'great',
#   'shaggy',
#   'grey',
#   'beard',
#   'and',
#   'sounded',
#   'as',
#   'tired',
#   'as',
#   'he',
#   'looked'],
#  ['we',
#   'might',
#   'all',
#   'have',
#   'been',
#   'better',
#   'for',
#   'bit',
#   'of',
#   'fresh',
#   'meat'],
#  ['the',
#   'raven',
#   'on',
#   'his',
#   'shoulder',
#   'bobbed',
#   'its',
#   'head',
#   'and',
#   'echoed',
#   'meat'],
#  ['meat'],
#  ['meat'],
#  ['we',
#   'could',
#   'cook',
#   'the',
#   'bloody',
#   'dogs',
#   'chett',
#   'thought',
#   'but',
#   'he',
#   'kept',
#   'his',
#   'mouth',
#   'shut',
#   'until',
#   'the',
#   'old',
#   'bear',
#   'sent',
#   'him',
#   'on',
#   'his',
#   'way'],
#  ['and',
#   'that',
#   'the',
#   'last',
#   'time',
#   'll',
#   'need',
#   'to',
#   'bow',
#   'my',
#   'head',
#   'to',
#   'that',
#   'one',
#   'he',
#   'thought',
#   'to',
#   'himself',
#   'with',
#   'satisfaction'],
#  ['it',
#   'seemed',
#   'to',
#   'him',
#   'that',
#   'it',
#   'was',
#   'growing',
#   'even',
#   'colder',
#   'which',
#   'he',
#   'would',
#   'have',
#   'swom'],
#  ['wasn', 'possible'],
#  ['the',
#   'dogs',
#   'huddled',
#   'together',
#   'miserably',
#   'in',
#   'the',
#   'hard',
#   'frozen',
#   'mud',
#   'and',
#   'chett',
#   'was',
#   'half',
#   'tempted',
#   'to',
#   'crawl',
#   'in',
#   'with',
#   'them'],
#  ['instead',
#   'he',
#   'wrapped',
#   'black',
#   'wool',
#   'scarf',
#   'round',
#   'the',
#   'lower',
#   'part',
#   'of',
#   'his',
#   'face',
#   'leaving',
#   'slit',
#   'for',
#   'his',
#   'mouth',
#   'between',
#   'the',
#   'winds'],
#  ['it',
#   'was',
#   'warmer',
#   'if',
#   'he',
#   'kept',
#   'moving',
#   'he',
#   'found',
#   'so',
#   'he',
#   'made',
#   'slow',
#   'circuit',
#   'of',
#   'the',
#   'perimeter',
#   'with',
#   'wad',
#   'of',
#   'sourleaf',
#   'sharing',
#   'chew',
#   'or',
#   'two',
#   'with',
#   'the',
#   'black',
#   'brothers',
#   'on',
#   'guard',
#   'and',
#   'hearing',
#   'what',
#   'they',
#   'had',
#   'to',
#   'say'],
#  ['none',
#   'of',
#   'the',
#   'men',
#   'on',
#   'the',
#   'day',
#   'watch',
#   'were',
#   'part',
#   'of',
#   'his',
#   'scheme',
#   'even',
#   'so',
#   'he',
#   'figured',
#   'it',
#   'was',
#   'good',
#   'to',
#   'have',
#   'some',
#   'sense',
#   'of',
#   'what',
#   'they',
#   'were',
#   'thinking'],
#  ['mostly',
#   'what',
#   'they',
#   'were',
#   'thinking',
#   'was',
#   'that',
#   'it',
#   'was',
#   'bloody',
#   'cold'],
#  ['the', 'wind', 'was', 'rising', 'as', 'the', 'shadows', 'lengthened'],
#  ['it',
#   'made',
#   'high',
#   'thin',
#   'sound',
#   'as',
#   'it',
#   'shivered',
#   'through',
#   'the',
#   'stones',
#   'of',
#   'the',
#   'ringwall'],
#  ['hate', 'that', 'sound', 'little', 'giant', 'said'],
#  ['it',
#   'sounds',
#   'like',
#   'babe',
#   'in',
#   'the',
#   'brush',
#   'wailing',
#   'away',
#   'for',
#   'milk'],
#  ['when',
#   'he',
#   'finished',
#   'the',
#   'circuit',
#   'and',
#   'returned',
#   'to',
#   'the',
#   'dogs',
#   'he',
#   'found',
#   'lark',
#   'waiting',
#   'for',
#   'him'],
#  ['the',
#   'officers',
#   'are',
#   'in',
#   'the',
#   'old',
#   'bear',
#   'tent',
#   'again',
#   'talking',
#   'something',
#   'fierce'],
#  ['that', 'what', 'they', 'do', 'said', 'chett'],
#  ['they',
#   're',
#   'highborn',
#   'all',
#   'but',
#   'blane',
#   'they',
#   'get',
#   'drunk',
#   'on',
#   'words',
#   'instead',
#   'of',
#   'wine'],
#  ['lark', 'sidled', 'closer'],
#  ['cheese',
#   'for',
#   'wits',
#   'keeps',
#   'going',
#   'on',
#   'about',
#   'the',
#   'bird',
#   'he',
#   'warned',
#   'glancing',
#   'about',
#   'to',
#   'make',
#   'certain',
#   'no',
#   'one',
#   'was',
#   'close'],
#  ['now',
#   'he',
#   'asking',
#   'if',
#   'we',
#   'cached',
#   'any',
#   'seed',
#   'for',
#   'the',
#   'damn',
#   'thing'],
#  ['it', 'raven', 'said', 'chett'],
#  ['it', 'eats', 'corpses'],
#  ['lark', 'grinned'],
#  ['his', 'might', 'be'],
#  ['or', 'yours'],
#  ['it',
#   'seemed',
#   'to',
#   'chett',
#   'that',
#   'they',
#   'needed',
#   'the',
#   'big',
#   'man',
#   'more',
#   'than',
#   'they',
#   'needed',
#   'lark'],
#  ['stop', 'fretting', 'about', 'small', 'paul'],
#  ['you', 'do', 'your', 'part', 'he', 'll', 'do', 'his'],
#  ['page',
#   'twilight',
#   'was',
#   'creeping',
#   'through',
#   'the',
#   'woods',
#   'by',
#   'the',
#   'time',
#   'he',
#   'rid',
#   'himself',
#   'of',
#   'the',
#   'sisterman',
#   'and',
#   'sat',
#   'down',
#   'to',
#   'edge',
#   'his',
#   'sword'],
#  ['it',
#   'was',
#   'bloody',
#   'hard',
#   'work',
#   'with',
#   'his',
#   'gloves',
#   'on',
#   'but',
#   'he',
#   'wasn',
#   'about',
#   'to',
#   'take',
#   'them',
#   'off'],
#  ['cold',
#   'as',
#   'it',
#   'was',
#   'any',
#   'fool',
#   'that',
#   'touched',
#   'steel',
#   'with',
#   'bare',
#   'hand',
#   'was',
#   'going',
#   'to',
#   'lose',
#   'patch',
#   'of',
#   'skin'],
#  ['the', 'dogs', 'whimpered', 'when', 'the', 'sun', 'went', 'down'],
#  ['he', 'gave', 'them', 'water', 'and', 'curses'],
#  ['half',
#   'night',
#   'more',
#   'and',
#   'you',
#   'can',
#   'find',
#   'your',
#   'own',
#   'feast'],
#  ['by', 'then', 'he', 'could', 'smell', 'supper'],
#  ['dywen',
#   'was',
#   'holding',
#   'forth',
#   'at',
#   'the',
#   'cookfire',
#   'as',
#   'chett',
#   'got',
#   'his',
#   'heel',
#   'of',
#   'hardbread',
#   'and',
#   'bowl',
#   'of',
#   'bean',
#   'and',
#   'bacon',
#   'soup',
#   'from',
#   'hake',
#   'the',
#   'cook'],
#  ['the', 'wood', 'too', 'silent', 'the', 'old', 'forester', 'was', 'saying'],
#  ['no', 'frogs', 'near', 'that', 'river', 'no', 'owls', 'in', 'the', 'dark'],
#  ['never', 'heard', 'no', 'deader', 'wood', 'than', 'this'],
#  ['them', 'teeth', 'of', 'yours', 'sound', 'pretty', 'dead', 'said', 'hake'],
#  ['dywen', 'clacked', 'his', 'wooden', 'teeth'],
#  ['no', 'wolves', 'neither'],
#  ['there', 'was', 'before', 'but', 'no', 'more'],
#  ['where', 'they', 'go', 'you', 'figure'],
#  ['someplace', 'warm', 'said', 'chett'],
#  ['of',
#   'the',
#   'dozen',
#   'odd',
#   'brothers',
#   'who',
#   'sat',
#   'by',
#   'the',
#   'fire',
#   'four',
#   'were',
#   'his'],
#  ['he',
#   'gave',
#   'each',
#   'one',
#   'hard',
#   'squinty',
#   'look',
#   'as',
#   'he',
#   'ate',
#   'to',
#   'see',
#   'if',
#   'any',
#   'showed',
#   'signs',
#   'of',
#   'breaking'],
#  ['dirk',
#   'seemed',
#   'calm',
#   'enough',
#   'sitting',
#   'silent',
#   'and',
#   'sharpening',
#   'his',
#   'blade',
#   'the',
#   'way',
#   'he',
#   'did',
#   'every',
#   'night'],
#  ['and', 'sweet', 'donnel', 'hill', 'was', 'all', 'easy', 'japes'],
#  ['he',
#   'had',
#   'white',
#   'teeth',
#   'and',
#   'fat',
#   'red',
#   'lips',
#   'and',
#   'yellow',
#   'locks',
#   'that',
#   'he',
#   'wore',
#   'in',
#   'an',
#   'artful',
#   'tumble',
#   'about',
#   'his',
#   'shoulders',
#   'and',
#   'he',
#   'claimed',
#   'to',
#   'be',
#   'the',
#   'bastard',
#   'of',
#   'some',
#   'lannister'],
#  ['maybe', 'he', 'was', 'at', 'that'],
#  ['chett',
#   'had',
#   'no',
#   'use',
#   'for',
#   'pretty',
#   'boys',
#   'nor',
#   'for',
#   'bastards',
#   'neither',
#   'but',
#   'sweet',
#   'donnel',
#   'seemed',
#   'like',
#   'to',
#   'hold',
#   'his',
#   'own'],
#  ['he',
#   'was',
#   'less',
#   'certain',
#   'about',
#   'the',
#   'forester',
#   'the',
#   'brothers',
#   'called',
#   'sawwood',
#   'more',
#   'for',
#   'his',
#   'snoring',
#   'than',
#   'for',
#   'anything',
#   'to',
#   'do',
#   'with',
#   'trees'],
#  ['just',
#   'now',
#   'he',
#   'looked',
#   'so',
#   'restless',
#   'he',
#   'might',
#   'never',
#   'snore',
#   'again'],
#  ['and', 'maslyn', 'was', 'worse'],
#  ['chett',
#   'could',
#   'see',
#   'sweat',
#   'trickling',
#   'down',
#   'his',
#   'face',
#   'despite',
#   'the',
#   'frigid',
#   'wind'],
#  ['the',
#   'beads',
#   'of',
#   'moisture',
#   'sparkled',
#   'in',
#   'the',
#   'firelight',
#   'like',
#   'so',
#   'many',
#   'little',
#   'wet',
#   'jewels'],
#  ['maslyn',
#   'wasn',
#   'eating',
#   'neither',
#   'only',
#   'staring',
#   'at',
#   'his',
#   'soup',
#   'as',
#   'if',
#   'the',
#   'smell',
#   'of',
#   'it',
#   'was',
#   'about',
#   'to',
#   'make',
#   'him',
#   'sick'],
#  ['ll', 'need', 'to', 'watch', 'that', 'one', 'chett', 'thought'],
#  ['assemble'],
#  ['the',
#   'shout',
#   'came',
#   'suddenly',
#   'from',
#   'dozen',
# ...
#  ['shouldn', 'think', 'that', 'would', 'trouble', 'them'],
#  ['am', 'as', 'good', 'fighter', 'as', 'you', 'she', 'said', 'defensively'],
#  ['was', 'one', 'of', 'king', 'renly', 'chosen', 'seven'],
#  ['with',
#   'his',
#   'own',
#   'hands',
#   'he',
#   'cloaked',
#   'me',
#   'with',
#   'the',
#   'striped',
#   'silk',
#   'of',
#   'the',
#   'rainbow',
#   'guard'],
#  ['the', 'rainbow', 'guard'],
#  ['you', 'and', 'six', 'other', 'girls', 'was', 'it'],
#  ['singer',
#   'once',
#   'said',
#   'that',
#   'all',
#   'maids',
#   'are',
#   'fair',
#   'in',
#   'silk',
#   'but',
#   'he',
#   'never',
#   'met',
#   'you',
#   'did',
#   'he'],
#  ['the', 'woman', 'turned', 'red'],
#  ['we', 'have', 'graves', 'to', 'dig'],
#  ['she', 'went', 'to', 'climb', 'the', 'tree'],
#  ['page',
#   'the',
#   'lower',
#   'limbs',
#   'of',
#   'the',
#   'oak',
#   'were',
#   'big',
#   'enough',
#   'for',
#   'her',
#   'to',
#   'stand',
#   'upon',
#   'once',
#   'she',
#   'gotten',
#   'up',
#   'the',
#   'trunk'],
#  ['she',
#   'walked',
#   'amongst',
#   'the',
#   'leaves',
#   'dagger',
#   'in',
#   'hand',
#   'cutting',
#   'down',
#   'the',
#   'corpses'],
#  ['flies',
#   'swarmed',
#   'around',
#   'the',
#   'bodies',
#   'as',
#   'they',
#   'fell',
#   'and',
#   'the',
#   'stench',
#   'grew',
#   'worse',
#   'with',
#   'each',
#   'one',
#   'she',
#   'dropped'],
#  ['this',
#   'is',
#   'deal',
#   'of',
#   'trouble',
#   'to',
#   'take',
#   'for',
#   'whores',
#   'ser',
#   'cleos',
#   'complained'],
#  ['what', 'are', 'we', 'supposed', 'to', 'dig', 'with'],
#  ['we',
#   'have',
#   'no',
#   'spades',
#   'and',
#   'will',
#   'not',
#   'use',
#   'my',
#   'sword',
#   'brienne',
#   'gave',
#   'shout'],
#  ['she', 'jumped', 'down', 'rather', 'than', 'climbing'],
#  ['to', 'the', 'boat'],
#  ['be', 'quick'],
#  ['there', 'sail'],
#  ['they',
#   'made',
#   'what',
#   'haste',
#   'they',
#   'could',
#   'though',
#   'jaime',
#   'could',
#   'hardly',
#   'run',
#   'and',
#   'had',
#   'to',
#   'be',
#   'pulled',
#   'back',
#   'up',
#   'into',
#   'the',
#   'skiff',
#   'by',
#   'his',
#   'cousin'],
#  ['brienne',
#   'shoved',
#   'off',
#   'with',
#   'an',
#   'oar',
#   'and',
#   'raised',
#   'sail',
#   'hurriedly'],
#  ['ser', 'cleos', 'll', 'need', 'you', 'to', 'row', 'as', 'well'],
#  ['he', 'did', 'as', 'she', 'bid'],
#  ['the',
#   'skiff',
#   'began',
#   'to',
#   'cut',
#   'the',
#   'water',
#   'bit',
#   'faster',
#   'current',
#   'wind',
#   'and',
#   'oars',
#   'all',
#   'worked',
#   'for',
#   'them'],
#  ['jaime', 'sat', 'chained', 'peering', 'upriver'],
#  ['only', 'the', 'top', 'of', 'the', 'other', 'sail', 'was', 'visible'],
#  ['with',
#   'the',
#   'way',
#   'the',
#   'red',
#   'fork',
#   'looped',
#   'it',
#   'looked',
#   'to',
#   'be',
#   'across',
#   'the',
#   'fields',
#   'moving',
#   'north',
#   'behind',
#   'screen',
#   'of',
#   'trees',
#   'while',
#   'they',
#   'moved',
#   'south',
#   'but',
#   'he',
#   'knew',
#   'that',
#   'was',
#   'deceptive'],
#  ['he', 'lifted', 'both', 'hands', 'to', 'shade', 'his', 'eyes'],
#  ['mud', 'red', 'and', 'watery', 'blue', 'he', 'announced'],
#  ['brienne',
#   'big',
#   'mouth',
#   'worked',
#   'soundlessly',
#   'giving',
#   'her',
#   'the',
#   'look',
#   'of',
#   'cow',
#   'chewing',
#   'its',
#   'cud'],
#  ['faster', 'ser'],
#  ['the',
#   'inn',
#   'soon',
#   'vanished',
#   'behind',
#   'them',
#   'and',
#   'they',
#   'lost',
#   'sight',
#   'of',
#   'the',
#   'top',
#   'of',
#   'the',
#   'sail',
#   'as',
#   'well',
#   'but',
#   'that',
#   'meant',
#   'nothing'],
#  ['once',
#   'the',
#   'pursuers',
#   'swung',
#   'around',
#   'the',
#   'loop',
#   'they',
#   'would',
#   'become',
#   'visible',
#   'again'],
#  ['we',
#   'can',
#   'hope',
#   'the',
#   'noble',
#   'tullys',
#   'will',
#   'stop',
#   'to',
#   'bury',
#   'the',
#   'dead',
#   'whores',
#   'suppose'],
#  ['the',
#   'prospect',
#   'of',
#   'returning',
#   'to',
#   'his',
#   'cell',
#   'did',
#   'not',
#   'appeal',
#   'to',
#   'jaime'],
#  ['tyrion',
#   'could',
#   'think',
#   'of',
#   'something',
#   'clever',
#   'now',
#   'but',
#   'all',
#   'that',
#   'occurs',
#   'to',
#   'me',
#   'is',
#   'to',
#   'go',
#   'at',
#   'them',
#   'with',
#   'sword'],
#  ['for',
#   'the',
#   'good',
#   'part',
#   'of',
#   'an',
#   'hour',
#   'they',
#   'played',
#   'peek',
#   'and',
#   'seek',
#   'with',
#   'the',
#   'pursuers',
#   'sweeping',
#   'around',
#   'bends',
#   'and',
#   'between',
#   'small',
#   'wooded',
#   'isles'],
#  ['just',
#   'when',
#   'they',
#   'were',
#   'starting',
#   'to',
#   'hope',
#   'that',
#   'somehow',
#   'they',
#   'might',
#   'have',
#   'left',
#   'behind',
#   'the',
#   'pursuit',
#   'the',
#   'distant',
#   'sail',
#   'became',
#   'visible',
#   'again'],
#  ['ser', 'cleos', 'paused', 'in', 'his', 'stroke'],
#  ['the', 'others', 'take', 'them'],
#  ['he', 'wiped', 'sweat', 'from', 'his', 'brow'],
#  ['row'],
#  ['brienne', 'said'],
#  ['that',
#   'is',
#   'river',
#   'galley',
#   'coming',
#   'after',
#   'us',
#   'jaime',
#   'announced',
#   'after',
#   'he',
#   'watched',
#   'for',
#   'while'],
#  ['with', 'every', 'stroke', 'it', 'seemed', 'to', 'grow', 'little', 'larger'],
#  ['nine', 'oars', 'on', 'each', 'side', 'which', 'means', 'eighteen', 'men'],
#  ['more',
#   'if',
#   'they',
#   'crowded',
#   'on',
#   'fighters',
#   'as',
#   'well',
#   'as',
#   'rowers'],
#  ['and', 'larger', 'sails', 'than', 'ours'],
#  ['we', 'cannot', 'outrun', 'her'],
#  ['ser', 'cleos', 'froze', 'at', 'his', 'oars'],
#  ['eighteen', 'you', 'said'],
#  ['six', 'for', 'each', 'of', 'us'],
#  ['want', 'eight', 'but', 'these', 'bracelets', 'hinder', 'me', 'somewhat'],
#  ['jaime', 'held', 'up', 'his', 'wrists'],
#  ['unless',
#   'the',
#   'lady',
#   'brienne',
#   'would',
#   'be',
#   'so',
#   'kind',
#   'as',
#   'to',
#   'unshackle',
#   'me'],
#  ['she',
#   'ignored',
#   'him',
#   'putting',
#   'all',
#   'her',
#   'effort',
#   'into',
#   'her',
#   'stroke'],
#  ['we', 'had', 'half', 'night', 'start', 'on', 'them', 'jaime', 'said'],
#  ['they',
#   've',
#   'been',
#   'rowing',
#   'since',
#   'dawn',
#   'resting',
#   'two',
#   'oars',
#   'at',
#   'time'],
#  ['they', 'll', 'be', 'exhausted'],
#  ['just',
#   'now',
#   'the',
#   'sight',
#   'of',
#   'our',
#   'sail',
#   'has',
#   'given',
#   'them',
#   'burst',
#   'of',
#   'strength',
#   'but',
#   'that',
#   'will',
#   'not',
#   'last'],
#  ['we',
#   'ought',
#   'to',
#   'be',
#   'able',
#   'to',
#   'kill',
#   'good',
#   'many',
#   'of',
#   'them'],
#  ['ser', 'cleos', 'gaped'],
#  ['but', 'there', 'are', 'eighteen'],
#  ['page', 'at', 'the', 'least'],
#  ['more', 'likely', 'twenty', 'or', 'twenty', 'five'],
#  ['his', 'cousin', 'groaned'],
#  ['we', 'can', 'hope', 'to', 'defeat', 'eighteen'],
#  ['did', 'say', 'we', 'could'],
#  ['the',
#   'best',
#   'we',
#   'can',
#   'hope',
#   'for',
#   'is',
#   'to',
#   'die',
#   'with',
#   'swords',
#   'in',
#   'our',
#   'hands'],
#  ['he', 'was', 'perfectly', 'sincere'],
#  ['jaime', 'lannister', 'had', 'never', 'been', 'afraid', 'of', 'death'],
#  ['brienne', 'broke', 'off', 'rowing'],
#  ['sweat',
#   'had',
#   'stuck',
#   'strands',
#   'of',
#   'her',
#   'flax',
#   'colored',
#   'hair',
#   'to',
#   'her',
#   'forehead',
#   'and',
#   'her',
#   'grimace',
#   'made',
#   'her',
#   'look',
#   'homelier',
#   'than',
#   'ever'],
#  ['you',
#   'are',
#   'under',
#   'my',
#   'protection',
#   'she',
#   'said',
#   'her',
#   'voice',
#   'so',
#   'thick',
#   'with',
#   'anger',
#   'that',
#   'it',
#   'was',
#   'almost',
#   'growl'],
#  ['he', 'had', 'to', 'laugh', 'at', 'such', 'fierceness'],
#  ['she', 'the', 'hound', 'with', 'teats', 'he', 'thought'],
#  ['or',
#   'would',
#   'be',
#   'if',
#   'she',
#   'had',
#   'any',
#   'teats',
#   'to',
#   'speak',
#   'of'],
#  ['then', 'protect', 'me', 'wench'],
#  ['or', 'free', 'me', 'to', 'protect', 'myself'],
#  ['the',
#   'galley',
#   'was',
#   'skimming',
#   'downriver',
#   'great',
#   'wooden',
#   'dragonfly'],
#  ['the',
#   'water',
#   'around',
#   'her',
#   'was',
#   'churned',
#   'white',
#   'by',
#   'the',
#   'furious',
#   'action',
#   'of',
#   'her',
#   'oars'],
#  ['she',
#   'was',
#   'gaining',
#   'visibly',
#   'the',
#   'men',
#   'on',
#   'her',
#   'deck',
#   'crowding',
#   'forward',
#   'as',
#   'she',
#   'came',
#   'on'],
#  ['metal',
#   'glinted',
#   'in',
#   'their',
#   'hands',
#   'and',
#   'jaime',
#   'could',
#   'see',
#   'bows',
#   'as',
#   'well'],
#  ['archers'],
#  ['he', 'hated', 'archers'],
#  ['at',
#   'the',
#   'prow',
#   'of',
#   'the',
#   'onrushing',
#   'galley',
#   'stood',
#   'stocky',
#   'man',
#   'with',
#   'bald',
#   'head',
#   'bushy',
#   'grey',
#   'eyebrows',
#   'and',
#   'brawny',
#   'arms'],
#  ['over',
#   'his',
#   'mail',
#   'he',
#   'wore',
#   'soiled',
#   'white',
#   'surcoat',
#   'with',
#   'weeping',
#   'willow',
#   'embroidered',
#   'in',
#   'pale',
#   'green',
#   'but',
#   'his',
#   'cloak',
#   'was',
#   'fastened',
#   'with',
#   'silver',
#   'trout'],
#  ['riverrun', 'captain', 'of', 'guards'],
#  ['in',
#   'his',
#   'day',
#   'ser',
#   'robin',
#   'ryger',
#   'had',
#   'been',
#   'notably',
#   'tenacious',
#   'fighter',
#   'but',
#   'his',
#   'day',
#   'was',
#   'done',
#   'he',
#   'was',
#   'of',
#   'an',
#   'age',
#   'with',
#   'hoster',
#   'tully',
#   'and',
#   'had',
#   'grown',
#   'old',
#   'with',
#   'his',
#   'lord'],
#  ['when',
#   'the',
#   'boats',
#   'were',
#   'fifty',
#   'yards',
#   'apart',
#   'jaime',
#   'cupped',
#   'his',
#   'hands',
#   'around',
#   'his',
#   'mouth',
#   'and',
#   'shouted',
#   'back',
#   'over',
#   'the',
#   'water'],
#  ['come', 'to', 'wish', 'me', 'godspeed', 'ser', 'robin'],
#  ['come',
#   'to',
#   'take',
#   'you',
#   'back',
#   'kingslayer',
#   'ser',
#   'robin',
#   'ryger',
#   'bellowed'],
#  ['how', 'is', 'it', 'that', 'you', 've', 'lost', 'your', 'golden', 'hair'],
#  ['hope',
#   'to',
#   'blind',
#   'my',
#   'enemies',
#   'with',
#   'the',
#   'sheen',
#   'off',
#   'my',
#   'head'],
#  ['it', 'worked', 'well', 'enough', 'for', 'you'],
#  ['ser', 'robin', 'was', 'unamused'],
#  ['the',
#   'distance',
#   'between',
#   'skiff',
#   'and',
#   'galley',
#   'had',
#   'shrunk',
#   'to',
#   'forty',
#   'yards'],
#  ['throw',
#   'your',
#   'oars',
#   'and',
#   'your',
#   'weapons',
#   'into',
#   'the',
#   'river',
#   'and',
#   'no',
#   'one',
#   'need',
#   'be',
#   'harmed'],
#  ['ser', 'cleos', 'twisted', 'around'],
#  ['jaime',
#   'tell',
#   'him',
#   'we',
#   'were',
#   'freed',
#   'by',
#   'lady',
#   'catelyn',
#   'an',
#   'exchange',
#   'of',
#   'captives',
#   'lawful'],
#  [],
#  [],
#  ['jaime', 'told', 'him', 'for', 'all', 'the', 'good', 'it', 'did'],
#  ['catelyn',
#   'stark',
#   'does',
#   'not',
#   'rule',
#   'in',
#   'riverrun',
#   'ser',
#   'robin',
#   'shouted',
#   'back'],
#  ['four',
#   'archers',
#   'crowded',
#   'into',
#   'position',
#   'on',
#   'either',
#   'side',
#   'of',
#   'him',
#   'two',
#   'standing',
#   'and',
#   'two',
#   'kneeling'],
#  ['cast', 'your', 'swords', 'into', 'the', 'water'],
#  ['have',
#   'no',
#   'sword',
#   'he',
#   'returned',
#   'but',
#   'if',
#   'did',
#   'stick',
#   'it',
#   'through',
#   'your',
#   'belly',
#   'and',
#   'hack',
#   'the',
#   'balls',
#   'off',
#   'those',
#   'four',
#   'cravens'],
#  ['flight', 'of', 'arrows', 'answered', 'him'],
#  ['one',
#   'thudded',
#   'into',
#   'the',
#   'mast',
#   'two',
#   'pierced',
#   'the',
#   'sail',
#   'and',
#   'the',
#   'fourth',
#   'missed',
#   'jaime',
#   'by',
#   'foot'],
#  ['another',
#   'of',
#   'the',
#   'red',
#   'fork',
#   'broad',
#   'loops',
#   'loomed',
#   'before',
#   'them'],
#  ['brienne', 'angled', 'the', 'skiff', 'across', 'the', 'bend'],
#  ['the',
#   'yard',
#   'swung',
#   'as',
#   'they',
#   'turned',
#   'their',
#   'sail',
#   'cracking',
#   'as',
#   'it',
#   'filled',
#   'with',
#   'wind'],
#  ['ahead', 'large', 'island', 'sat', 'in', 'page', 'midstream'],
#  ['the', 'main', 'channel', 'flowed', 'right'],
#  ['to',
#   'the',
#   'left',
#   'cutoff',
#   'ran',
#   'between',
#   'the',
#   'island',
#   'and',
#   'the',
#   'high',
#   'bluffs',
#   'of',
#   'the',
#   'north',
#   'shore'],
#  ['brienne',
#   'moved',
#   'the',
#   'tiller',
#   'and',
#   'the',
#   'skiff',
#   'sheared',
#   'left',
#   'sail',
#   'rippling'],
#  ['jaime', 'watched', 'her', 'eyes'],
#  ['pretty', 'eyes', 'he', 'thought', 'and', 'calm'],
#  ['he', 'knew', 'how', 'to', 'read', 'man', 'eyes'],
#  ['he', 'knew', 'what', 'fear', 'looked', 'like'],
#  ['she', 'is', 'determined', 'not', 'desperate'],
#  ['thirty',
#   'yards',
#   'behind',
#   'the',
#   'galley',
#   'was',
#   'entering',
#   'the',
#   'bend'],
#  ['ser', 'cleos', 'take', 'the', 'tiller', 'the', 'wench', 'commanded'],
#  ['kingslayer',
#   'take',
#   'an',
#   'oar',
#   'and',
#   'keep',
#   'us',
#   'off',
#   'the',
#   'rocks'],
#  ['as', 'my', 'lady', 'commands'],
#  ['an',
#   'oar',
#   'was',
#   'not',
#   'sword',
#   'but',
#   'the',
#   'blade',
#   'could',
#   'break',
#   'man',
#   'face',
#   'if',
#   'well',
#   'swung',
#   'and',
#   'the',
#   'shaft',
#   'could',
#   'be',
#   'used',
#   'to',
#   'parry'],
#  ['ser',
#   'cleos',
#   'shoved',
#   'the',
#   'oar',
#   'into',
#   'jaime',
#   'hand',
#   'and',
#   'scrambled',
#   'aft'],
#  ['they',
#   'crossed',
#   'the',
#   'head',
#   'of',
#   'the',
#   'island',
#   'and',
#   'turned',
#   'sharply',
#   'down',
#   'the',
#   'cutoff',
#   'sending',
#   'wash',
#   'of',
#   'water',
#   'against',
#   'the',
#   'face',
#   'of',
#   'the',
#   'bluff',
#   'as',
#   'the',
#   'boat',
#   'tilted'],
#  ['the',
#   'island',
#   'was',
#   'densely',
#   'wooded',
#   'tangle',
#   'of',
#   'willows',
#   'oaks',
#   'and',
#   'tall',
#   'pines',
#   'that',
#   'cast',
#   'deep',
#   'shadows',
#   'across',
#   'the',
#   'rushing',
#   'water',
#   'hiding',
#   'snags',
#   'and',
#   'the',
#   'rotted',
#   'trunks',
#   'of',
#   'drowned',
#   'trees'],
#  ['to',
#   'their',
#   'left',
#   'the',
#   'bluff',
#   'rose',
#   'sheer',
#   'and',
#   'rocky',
#   'and',
#   'at',
#   'its',
#   'foot',
#   'the',
#   'river',
#   'foamed',
#   'whitely',
#   'around',
#   'broken',
#   'boulders',
#   'and',
#   'tumbles',
#   'of',
#   'rock',
#   'fallen',
#   'from',
#   'the',
#   'cliff',
#   'face'],
#  ['they',
#   'passed',
#   'from',
#   'sunlight',
#   'into',
#   'shadow',
#   'hidden',
#   'from',
#   'the',
#   'galley',
#   'view',
#   'between',
#   'the',
#   'green',
#   'wall',
#   'of',
#   'the',
#   'trees',
#   'and',
#   'the',
#   'stony',
#   'grey',
#   'brown',
#   'bluff'],
#  ['few',
#   'moments',
#   'respite',
#   'from',
#   'the',
#   'arrows',
#   'jaime',
#   'thought',
#   'pushing',
#   'them',
#   'off',
#   'half',
#   'submerged',
#   'boulder'],
#  ['the', 'skiff', 'rocked'],
#  ['he',
#   'heard',
#   'soft',
#   'splash',
#   'and',
#   'when',
#   'he',
#   'glanced',
#   'around',
#   'brienne',
#   'was',
#   'gone'],
#  ['moment',
#   'later',
#   'he',
#   'spied',
#   'her',
#   'again',
#   'pulling',
#   'herself',
#   'from',
#   'the',
#   'water',
#   'at',
#   'the',
#   'base',
#   'of',
#   'the',
#   'bluff'],
#  ['she',
#   'waded',
#   'through',
#   'shallow',
#   'pool',
#   'scrambled',
#   'over',
#   'some',
#   'rocks',
#   'and',
#   'began',
#   'to',
#   'climb'],
#  ['ser', 'cleos', 'goggled', 'mouth', 'open'],
#  ['fool', 'thought', 'jaime'],
#  ['ignore', 'the', 'wench', 'he', 'snapped', 'at', 'his', 'cousin'],
#  ['steer'],
#  ['they', 'could', 'see', 'the', 'sail', 'moving', 'behind', 'the', 'trees'],
#  ['the',
#   'river',
#   'galley',
#   'came',
#   'into',
#   'full',
#   'view',
#   'at',
#   'the',
#   'top',
#   'of',
#   'the',
#   'cutoff',
#   'twenty',
#   'five',
#   'yards',
#   'behind'],
#  ['her',
#   'bow',
#   'swung',
#   'hard',
#   'as',
#   'she',
#   'came',
#   'around',
#   'and',
#   'half',
#   'dozen',
#   'arrows',
#   'took',
#   'flight',
#   'but',
#   'all',
#   'went',
#   'well',
#   'wide'],
#  ['the',
#   'motion',
#   'of',
#   'the',
#   'two',
#   'boats',
#   'was',
#   'giving',
#   'the',
#   'archers',
#   'difficulty',
#   'but',
#   'jaime',
#   'knew',
#   'they',
#   'soon',
#   'enough',
#   'learn',
#   'to',
#   'compensate'],
#  ['brienne',
#   'was',
#   'halfway',
#   'up',
#   'the',
#   'cliff',
#   'face',
#   'pulling',
#   'herself',
#   'from',
#   'handhold',
#   'to',
#   'handhold'],
#  ['ryger',
#   'sure',
#   'to',
#   'see',
#   'her',
#   'and',
#   'once',
#   'he',
#   'does',
#   'he',
#   'll',
#   'have',
#   'those',
#   'bowmen',
#   'bring',
#   'her',
#   'down'],
#  ['jaime',
#   'decided',
#   'to',
#   'see',
#   'if',
#   'the',
#   'old',
#   'man',
#   'pride',
#   'would',
#   'make',
#   'him',
#   'stupid'],
#  ['ser', 'robin', 'he', 'shouted', 'hear', 'me', 'for', 'moment'],
#  ['ser',
#   'robin',
#   'raised',
#   'hand',
#   'and',
#   'his',
#   'archers',
#   'lowered',
#   'their',
#   'bows'],
#  ['say', 'what', 'you', 'will', 'kingslayer', 'but', 'say', 'it', 'quickly'],
#  ['the',
#   'skiff',
#   'swung',
#   'through',
#   'litter',
#   'of',
#   'broken',
#   'stones',
#   'as',
#   'jaime',
#   'called',
#   'out',
#   'know',
#   'better',
#   'way',
#   'to',
#   'settle',
#   'this',
#   'single',
#   'combat'],
#  ['you', 'and', 'was', 'not', 'born', 'this', 'morning', 'lannister'],
#  ['no', 'but', 'you', 're', 'like', 'to', 'die', 'this', 'afternoon'],
#  ['jaime',
#   'raised',
#   'his',
#   'hands',
#   'so',
#   'the',
#   'other',
#   'could',
#   'see',
#   'the',
#   'manacles'],
#  ['ll', 'fight', 'you', 'in', 'chains'],
#  ['what', 'could', 'you', 'fear'],
#  ...]

# %%
len(story)
# Out:
# 145020

# %%
model = gensim.models.Word2Vec(
    window=10,
    min_count=2
)

# %%
model.build_vocab(story)

# %%
model.train(story, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (6570465, 8628190)

# %%
model.wv.most_similar('queen')
# Out:
# [('princess', 0.7420772910118103),
#  ('margaery', 0.6915709376335144),
#  ('daenerys', 0.6897676587104797),
#  ('cersei', 0.6798440217971802),
#  ('prince', 0.6554971933364868),
#  ('targaryen', 0.649296224117279),
#  ('mother', 0.6359758377075195),
#  ('stormborn', 0.6305001974105835),
#  ('joffrey', 0.623916506767273),
#  ('myrcella', 0.6217859983444214)]

# %%
model.wv.doesnt_match(['jon', 'rikon', 'robb', 'arya', 'sansa', 'bran'])
# Out:
# 'jon'

# %%
model.wv['king']
# Out:
# array([ 1.51265   ,  1.0246325 , -1.4045793 ,  2.4083319 , -1.4150428 ,
#        -1.1408298 ,  1.6278191 ,  1.8680526 , -3.4692156 ,  0.33286586,
#        -0.76457787, -2.619756  ,  0.15862633,  1.2143937 , -3.4895227 ,
#        -0.16524212,  0.57752675,  2.0103137 , -1.2140894 , -0.05535822,
#        -0.23309453,  0.3024851 ,  3.4306815 , -3.4860165 , -2.474758  ,
#        -0.5893093 , -2.0789752 , -1.0650475 , -0.813968  ,  2.0794    ,
#        -1.4186181 ,  2.0849438 ,  0.94094545, -0.11124951, -0.64401114,
#        -0.9000272 , -1.0737953 , -0.5115462 ,  2.3727639 , -2.3423176 ,
#         0.36158416,  1.437589  ,  3.143647  ,  0.726451  , -1.0669798 ,
#        -1.7352619 ,  0.5147562 , -2.2000365 ,  4.140276  , -3.636417  ,
#        -3.295967  , -0.785692  , -0.4870825 , -2.4456837 ,  3.3942122 ,
#        -0.96245146, -0.6204994 , -0.13279098,  1.9864792 ,  1.2679467 ,
#         1.7890877 ,  1.2301997 ,  0.18926436,  1.484021  ,  0.65311015,
#         0.74261594, -2.0225947 , -0.36101806, -1.258164  , -3.2425287 ,
#        -0.48865142, -0.16424567,  4.8332715 , -0.43196887,  1.8262268 ,
#         1.0156043 , -1.074711  , -0.9876538 ,  2.3520596 , -2.6311846 ,
#         0.08849664,  2.1786451 , -0.7448359 , -0.35714746, -3.2397194 ,
#        -2.4311998 ,  0.38763434,  1.8552954 , -0.09006319, -1.154445  ,
#        -0.79107046,  1.9536012 , -0.2599425 , -3.4423158 , -1.4273785 ,
#        -3.2850037 , -0.29562685,  0.53389394, -0.24934863,  1.3845199 ],
#       dtype=float32)

# %%
model.wv.similarity('arya', 'sansa')
# Out:
# np.float32(0.8507173)

# %%
model.wv.similarity('tywin', 'sansa')
# Out:
# np.float32(0.21891595)

# %%
model.wv.get_normed_vectors()
# Out:
# array([[ 0.02394853, -0.09928109,  0.03303447, ..., -0.03261686,
#         -0.08423471,  0.09974037],
#        [-0.08178785, -0.21908228,  0.07738341, ..., -0.05415023,
#         -0.21488251,  0.11974564],
#        [ 0.24019754, -0.0243242 , -0.15450332, ..., -0.07673152,
#          0.06799629, -0.10717694],
#        ...,
#        [ 0.03900234,  0.09180316, -0.2581013 , ..., -0.06625322,
#          0.15562949, -0.04160527],
#        [ 0.01482526, -0.0097283 ,  0.03235356, ...,  0.00554029,
#         -0.08979618,  0.10029971],
#        [ 0.09070135, -0.06803884, -0.11177964, ...,  0.14281283,
#         -0.12582803,  0.15536188]], shape=(17453, 100), dtype=float32)

# %%
y = model.wv.index_to_key

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3)

# %%
X = pca.fit_transform(model.wv.get_normed_vectors())

# %%
X.shape
# Out:
# (17453, 3)

# %%
import plotly.express as px

# %%
fig = px.scatter_3d(X[:100], x=0, y=1, z=2, color=y[:100])
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 2
#       1 fig = px.scatter_3d(X[:100], x=0, y=1, z=2, color=y[:100])
# ----> 2 fig.show()
#
# File ~/Codes/Natural Langauge Processing/naturalang/lib/python3.12/site-packages/plotly/basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#    3387 """
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#    3389 specified by the renderer argument
#    (...)   3416 None
#    3417 """
#    3418 import plotly.io as pio
# -> 3420 return pio.show(self, *args, **kwargs)
#
# File ~/Codes/Natural Langauge Processing/naturalang/lib/python3.12/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
